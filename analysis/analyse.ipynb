# %%
import csv
import json
import pandas as pd
import networkx as nx
from collections import Counter

# %%
g = nx.MultiDiGraph()

# %%
df_metanodes = pd.read_csv('data/metanodes.tsv', sep='\t')

# %%
df_metanodes
# Out:
#                                      id      type  \
# 0                ARCHS4SignatureResults      Data
# 1    AlleleRegistryExternalRecordsTable      Data
# 2          AlleleSpecificEvidencesTable      Data
# 3                               AnnData      Data
# 4                             BokehPlot      Data
# ..                                  ...       ...
# 351          VariantInfoFromVariantTerm  Resolver
# 352               VisualizeLibrarySizes  Resolver
# 353    VisualizeLibrarySizesFromAnnData  Resolver
# 354                         VolcanoPlot  Resolver
# 355      ZScoreNormalizeGeneCountMatrix  Resolver
#
#                             input           output  \
# 0                             NaN              NaN
# 1                             NaN              NaN
# 2                             NaN              NaN
# 3                             NaN              NaN
# 4                             NaN              NaN
# ..                            ...              ...
# 351   {"variant":"Term[Variant]"}      VariantInfo
# 352  {"matrix":"GeneCountMatrix"}       PlotlyPlot
# 353         {"anndata":"AnnData"}       PlotlyPlot
# 354       {"sig":"GeneSignature"}       PlotlyPlot
# 355  {"matrix":"GeneCountMatrix"}  GeneCountMatrix
#
#                                                label  \
# 0                    ARCHS4 Signature Search Results
# 1                 AlleleRegistryExternalRecordsTable
# 2                    Allele Specific Evidences Table
# 3                                     Annotated data
# 4                                         Bokeh Plot
# ..                                               ...
# 351                   Resolve Variant Info from Term
# 352     Library Size Bar Plot from Gene Count Matrix
# 353          Library Size Bar Plot from AnnData File
# 354  Volcano Plot from Differential Expression Table
# 355            Z Score Normalize A Gene Count Matrix
#
#                                            description color
# 0                      ARCHS4 Signatures Query Results   NaN
# 1                                                  NaN   NaN
# 2                 A table of allele specific evidences   NaN
# 3    A gene count matrix paired with sample annotat...   NaN
# 4    A figure created with the [Bokeh Library](http...   NaN
# ..                                                 ...   ...
# 351  Resolve variant info (Allele registry API) fro...   NaN
# 352  Construct a bar plot which displays the total ...   NaN
# 353  Construct a bar plot which displays the total ...   NaN
# 354  Construct a scatter plot which displays the lo...   NaN
# 355  Z-score normalize a gene count matrix, return ...   NaN
#
# [356 rows x 7 columns]

# %%
for id, node in df_metanodes.iterrows():
  g.add_node(id, **node.to_dict())

metanodes = df_metanodes.set_index('id')
metanode_lookup = df_metanodes.reset_index().set_index('id')['index'].to_dict()

# %%
df = pd.read_csv('data/dump.csv', header=None, names=['id', 'parent', 'process_type', 'input_data_type'])

# %%
df
# Out:
#                                         id  \
# 0     3af79be2-c018-4926-6298-076b7c8b4dbb
# 1     15293aeb-7703-3a75-e4d4-bf8028159a0c
# 2     ecef3f2a-4357-88b6-97d5-4199f370d6d5
# 3     031adf2a-6035-1bd4-1d7e-22db34991c80
# 4     20946800-c926-b0cb-2ea4-2416250ca2c4
# ...                                    ...
# 2435  c689c679-f02a-3f90-06b1-873a5d94cb53
# 2436  5a11a546-052a-0a0c-799c-ec8fcfaef122
# 2437  725f2705-8a6f-1d6e-53b3-142ae21e108c
# 2438  c06b0d4b-ef84-4a56-0f60-afecab26181c
# 2439  2255f6bb-0003-4245-3a27-ed67aa101303
#
#                                     parent  \
# 0     6643d55a-355e-3371-c6b7-45fc96a74513
# 1                                      NaN
# 2     15293aeb-7703-3a75-e4d4-bf8028159a0c
# 3                                      NaN
# 4     031adf2a-6035-1bd4-1d7e-22db34991c80
# ...                                    ...
# 2435  e4970b43-04fd-0362-d73a-bab64815ae3b
# 2436  c689c679-f02a-3f90-06b1-873a5d94cb53
# 2437  5a11a546-052a-0a0c-799c-ec8fcfaef122
# 2438  725f2705-8a6f-1d6e-53b3-142ae21e108c
# 2439  c06b0d4b-ef84-4a56-0f60-afecab26181c
#
#                                            process_type input_data_type
# 0                              OneScoredT[Scored[Gene]]      Term[Gene]
# 1                                             FileInput         FileURL
# 2                               GeneCountMatrixFromFile             NaN
# 3                                             FileInput         FileURL
# 4                               GeneCountMatrixFromFile             NaN
# ...                                                 ...             ...
# 2435  ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert...             NaN
# 2436                             EnrichrSetTToGMT[Drug]             NaN
# 2437                                      GenesetsToGMT             GMT
# 2438                                     GMTConcatenate             NaN
# 2439                                   SupervennFromGMT             NaN
#
# [2440 rows x 4 columns]

# %%
df['input'] = df['process_type'].apply(lambda spec: metanodes.loc[spec, 'input'] if spec in metanodes.index else None)
df['output'] = df['process_type'].apply(lambda spec: metanodes.loc[spec, 'output'] if spec in metanodes.index else None)

# %%
for _, edge in df.iterrows():
  if edge['process_type'] not in metanode_lookup: continue
  process_type_id = metanode_lookup[edge['process_type']]
  if edge['output']:
    g.add_edge(process_type_id, metanode_lookup[edge['output']])
  if edge['input']:
    for arg, input_type in json.loads(edge['input']).items():
      if type(input_type) == list:
        g.add_edge(metanode_lookup[input_type[0]], process_type_id)
      else:
        g.add_edge(metanode_lookup[input_type], process_type_id)

# %%
nx.write_graphml(g, 'data/output.graphml')

# %%
def n_gram(n, iterable):
  gram = []
  for item in iterable:
    gram.append(item)
    if len(gram) == n:
      yield tuple(gram)
      gram.pop(0)

# %%
with open('data/analytics.tsv', 'r') as fr:
  grams = {1: Counter(), 2: Counter(), 3: Counter()}
  for hits, *ids in csv.reader(fr, delimiter='\t'):
    for n, c in grams.items():
      for g in n_gram(n, ids):
        c.update({ g: int(hits) })

# %%
grams[1].most_common()
# Out:
# [(('FileInput',), 4189),
#  (('EnrichrSetTToGMT[Phenotype]',), 2624),
#  (('GMTUnion',), 2348),
#  (('GeneCountMatrixFromFile',), 1907),
#  (('EnrichrGenesetSearch',), 1855),
#  (('Input[Gene]',), 1746),
#  (('ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]',), 1394),
#  (('Input[Variant]',), 1360),
#  (('TargetRangerScreenTargets[GTEx_transcriptomics]',), 1293),
#  (('GeneSigFromFile',), 1239),
#  (('OneScoredT[Scored[Gene]]',), 1133),
#  (('LINCSL1000ReverseSearch',), 1060),
#  (('Input[Drug]',), 958),
#  (('GeneTermFromVariantTerm',), 901),
#  (('ExtractEnrichrTermSearch[Human_Phenotype_Ontology]',), 838),
#  (('Input[Pathway]',), 832),
#  (('EnrichrTermSearch[Pathway]',), 827),
#  (('GTExTissueExpressionFromGene',), 732),
#  (('UpGeneSetFromSignature',), 695),
#  (('ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',), 664),
#  (('ExtractEnrichrTermSearch[GWAS_Catalog_2019]',), 630),
#  (('EnrichrSetTToGMT[Pathway]',), 605),
#  (('KFTumorExpressionFromGene',), 589),
#  (('Input[Phenotype]',), 585),
#  (('LINCSL1000ReverseSearchExtract[Drug, Down]',), 536),
#  (('EnrichrTermSearch[Phenotype]',), 522),
#  (('ExtractEnrichrTermSearch[GO_Biological_Process_2021]',), 520),
#  (('DownGeneSetFromSignature',), 494),
#  (('ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_up]',), 488),
#  (('GeneInfoFromGeneTerm',), 458),
#  (('SigComLINCSGeneSetSearch',), 458),
#  (('EnrichrTermSearch[Drug]',), 446),
#  (('MetGeneSearch',), 439),
#  (('ScoredGenesFromSignature',), 407),
#  (('Input[Set[Gene]]',), 393),
#  (('MetadataMatrixFromFile',), 359),
#  (('SetFromScored[Scored[Drug]]',), 359),
#  (('TermToSet[Term[Gene]]',), 353),
#  (('LINCSL1000ReverseSearchExtract[Gene, Up]',), 347),
#  (('GMTConsensus',), 345),
#  (('IDGFilter[Scored[Gene], all]',), 325),
#  (('LINCSL1000ReverseSearchExtract[Gene, Down]',), 323),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix',), 316),
#  (('VariantInfoFromVariantTerm',), 309),
#  (('ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',), 308),
#  (('EnrichrSetTToGMT[Drug]',), 301),
#  (('ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',),
#   296),
#  (('MetgeneMetabolites',), 294),
#  (('GTExTissueExpression',), 267),
#  (('Limma-Voom',), 263),
#  (('GetRegulatoryElementsForGeneInfoFromGene',), 253),
#  (('SigComLINCSSignatureSearch',), 248),
#  (('Input[Disease]',), 247),
#  (('MetGeneRxns',), 243),
#  (('PCAGraph',), 236),
#  (('Input[Set[Variant]]',), 231),
#  (('AnnDataFromFile',), 216),
#  (('ProteinProductInformation',), 213),
#  (('EnrichrTermSearch[Disease]',), 210),
#  (('KFTumorExpression',), 201),
#  (('ExtractEnrichrTermSearch[KEGG_2021_Human]',), 197),
#  (('EnrichrSetTToGMT[Gene]',), 195),
#  (('VolcanoPlot',), 189),
#  (('EnrichrGeneSearch',), 179),
#  (('ExtractSigComLINCSSignatureSearch[LINCS L1000 Chemical Perturbagens]',),
#   178),
#  (('Input[Regulatory_Element]',), 143),
#  (('ProteinProductInformationFromGene',), 142),
#  (('GeneSet_CTD_Kegg',), 142),
#  (('RegElementInfoFromRegElementTerm',), 138),
#  (('CDSignatureFromCounts',), 136),
#  (('GetAlleleRegistryExternalRecordsForVariant',), 127),
#  (('EnrichrTermSearch[Gene]',), 116),
#  (('GetRegulatoryElementForThisVariant',), 114),
#  (('GeneSet_CTD_String',), 110),
#  (('ExtractEnrichrTermSearch[ENCODE_TF_ChIP-seq_2015]',), 101),
#  (('MetGeneStudies',), 99),
#  (('ExtractEnrichrTermSearch[ClinVar_2019]',), 99),
#  (('ExtractEnrichrGeneSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',), 98),
#  (('GenesetsToGMT',), 95),
#  (('GMTConcatenate',), 93),
#  (('BarplotFrom[Scored[Tissue]]',), 92),
#  (('ExtractEnrichrTermSearch[ChEA_2022]',), 79),
#  (('ExtractEnrichrGeneSearch[LINCS_L1000_CRISPR_KO_Consensus_Sigs]',), 74),
#  (('GetRegulatoryElementsForGeneInfo',), 72),
#  (('LINCSL1000ReverseSearchExtract[Drug, Up]',), 69),
#  (('BarplotFrom[[TumorGeneExpression]]',), 65),
#  (('GetGenesForRegulatoryElementInfo',), 64),
#  (('GetVariantListForRegulatoryElementInfo',), 63),
#  (('OneScoredT[Scored[Tissue]]',), 62),
#  (('Highly_Connected_Genes',), 61),
#  (('GeneSetIDConv',), 59),
#  (('ExtractEnrichrTermSearch[ARCHS4_TFs_Coexp]',), 52),
#  (('TopKScoredT[Scored[Tissue]]',), 47),
#  (('MeanScoredT[Drug]',), 45),
#  (('OneSetT[Set[Drug]]',), 45),
#  (('ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_down]',), 43),
#  (('PCAGraphWithMetadata',), 43),
#  (('DrugSetsToDMT',), 42),
#  (('FetchStringDBPPI',), 41),
#  (('Guilty_By_Association_Genes',), 40),
#  (('VarinatInfoFromVariantTerm',), 38),
#  (('SupervennFromGMT',), 36),
#  (('StringDBPPI_to_GraphPlot',), 36),
#  (('MyVariantInfoFromVariantTerm',), 34),
#  (('ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]',), 34),
#  (('GetAlleleSpecificEvidencesForThisVariant',), 33),
#  (('VisualizeLibrarySizesFromAnnData',), 33),
#  (('Input[Set[Drug]]',), 32),
#  (('ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_up]',), 32),
#  (('GMTFromFile',), 31),
#  (('StringDBPPI_to_GeneSet',), 31),
#  (('Input[Set[Regulatory_Element]]',), 30),
#  (('Input[Tissue]',), 25),
#  (('EnrichrTermSearch[Tissue]',), 25),
#  (('Input[Metabolite]',), 21),
#  (('TargetRangerScreenTargets[ARCHS4]',), 21),
#  (('SetFromScored[Scored[Gene]]',), 21),
#  (('MetGeneRxnsSet',), 20),
#  (('LabelAnnDataMetadata',), 20),
#  (('CTD_Graph_Nodes',), 17),
#  (('BarplotFrom[Scored[Drug]]',), 17),
#  (('ARCHS4SignatureSearch[Human]',), 17),
#  (('SupervennFromDMT',), 16),
#  (('TopKScoredT[Scored[Drug]]',), 15),
#  (('FilterFDAApprovedDrugs[Scored[Drug]]',), 15),
#  (('GetxQTL_EvidencesDataForVariantInfo',), 14),
#  (('ExtractEnrichrGenesetSearch[ENCODE_TF_ChIP-seq_2015]',), 14),
#  (('BarplotFrom[Scored[Gene]]',), 12),
#  (('GeneIDConv',), 11),
#  (('MetaboliteInfo',), 11),
#  (('acss2 gene',), 11),
#  (('MetgeneMetabolitesGeneSet',), 11),
#  (('TermToSet[Term[Drug]]',), 11),
#  (('GeneshotGeneSetAugmentation[coexpression]',), 10),
#  (('ExtractEnrichrGenesetSearch[GTEx_Tissues_V8_2023]',), 9),
#  (('ExtractEnrichrGenesetSearch[ChEA_2022]',), 9),
#  (('Input[Set[Metabolite]]',), 8),
#  (('MetGeneStudiesGeneSet',), 8),
#  (('LogNormalizeGeneCountMatrix',), 7),
#  (('VisualizeLibrarySizes',), 7),
#  (('Transpose',), 7),
#  (('PCABokehPlotFromGeneCountMatrix',), 6),
#  (('ExtractEnrichrGenesetSearch[ARCHS4_Tissues]',), 6),
#  (('c1',), 6),
#  (('MetaboliteSetInfo',), 6),
#  (('BarChartFrom[Scored[Gene]]',), 6),
#  (('ExtractProteinIDs',), 5),
#  (('BRCA',), 5),
#  (('IDGFilter[Set[Gene], darkionchannel]',), 5),
#  (('TopKScoredT[Scored[Gene]]',), 5),
#  (('GetRegulatoryElementsForVariantInfo',), 4),
#  (('IDGFilter[Set[Gene], all]',), 4),
#  (('IDGFilter[Set[Gene], ionchannel]',), 4),
#  (('ExtractEnrichrGenesetSearch[GO_Biological_Process_2021]',), 3),
#  (('OneSetT[Set[Gene]]',), 3),
#  (('PCAGraphWithoutMetadata',), 3),
#  (('MGMetTable2MetSet',), 3),
#  (('GMTFromSignature',), 2),
#  (('GlycosylationsFromProteins',), 2),
#  (('ExtractEnrichrGeneSearch[ARCHS4_TFs_Coexp]',), 2),
#  (('IDGFilter[Set[Gene], darkgpcr]',), 2),
#  (('GMTIntersection',), 2),
#  (('IDGFilter[Set[Gene], gpcr]',), 2),
#  (('EnrichrSetTToSetT[Pathway]',), 2),
#  (('ExtractEnrichrGenesetSearch[WikiPathways_2019_Human]',), 2),
#  (('ExtractEnrichrTermSearch[GTEx_Tissues_V8_2023]',), 2),
#  (('ExtractEnrichrTermSearch[KEGG_2019_Human]',), 2),
#  (('FilterFDAApprovedDrugs[Set[Drug]]',), 2),
#  (('BarplotFrom[Scored[Pathway]]',), 1),
#  (('ExtractEnrichrTermSearch[ARCHS4_Tissues]',), 1),
#  (('GeneTermFromMyVariantInfo',), 1),
#  (('SomeSetT[Set[Gene]]',), 1),
#  (('Call_MetENP_on_MetSet',), 1)]

# %%
grams[2].most_common()
# Out:
# [(('FileInput', 'GeneCountMatrixFromFile'), 1887),
#  (('GeneCountMatrixFromFile',
#    'TargetRangerScreenTargets[GTEx_transcriptomics]'),
#   1293),
#  (('FileInput', 'GeneSigFromFile'), 1239),
#  (('EnrichrSetTToGMT[Phenotype]', 'GMTUnion'), 1154),
#  (('TargetRangerScreenTargets[GTEx_transcriptomics]',
#    'OneScoredT[Scored[Gene]]'),
#   963),
#  (('ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   914),
#  (('Input[Variant]', 'GeneTermFromVariantTerm'), 846),
#  (('Input[Pathway]', 'EnrichrTermSearch[Pathway]'), 803),
#  (('OneScoredT[Scored[Gene]]', 'LINCSL1000ReverseSearch'), 792),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]'),
#   664),
#  (('GMTUnion', 'GMTUnion'), 636),
#  (('GeneSigFromFile', 'FileInput'), 605),
#  (('EnrichrSetTToGMT[Pathway]', 'GMTUnion'), 540),
#  (('EnrichrSetTToGMT[Phenotype]', 'EnrichrSetTToGMT[Phenotype]'), 501),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_up]'),
#   488),
#  (('ExtractEnrichrTermSearch[GWAS_Catalog_2019]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   483),
#  (('EnrichrTermSearch[Pathway]',
#    'ExtractEnrichrTermSearch[Human_Phenotype_Ontology]'),
#   463),
#  (('ExtractEnrichrTermSearch[Human_Phenotype_Ontology]',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]'),
#   436),
#  (('GMTUnion', 'SigComLINCSGeneSetSearch'), 429),
#  (('DownGeneSetFromSignature', 'EnrichrGenesetSearch'), 420),
#  (('ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]',
#    'ExtractEnrichrTermSearch[GO_Biological_Process_2021]'),
#   416),
#  (('ExtractEnrichrTermSearch[GO_Biological_Process_2021]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   393),
#  (('Input[Phenotype]', 'Input[Drug]'), 388),
#  (('Input[Drug]', 'Input[Drug]'), 375),
#  (('Input[Drug]', 'EnrichrTermSearch[Phenotype]'), 362),
#  (('EnrichrTermSearch[Phenotype]',
#    'ExtractEnrichrTermSearch[GWAS_Catalog_2019]'),
#   354),
#  (('EnrichrSetTToGMT[Phenotype]', 'EnrichrSetTToGMT[Pathway]'), 351),
#  (('LINCSL1000ReverseSearch', 'LINCSL1000ReverseSearchExtract[Drug, Down]'),
#   344),
#  (('LINCSL1000ReverseSearch', 'LINCSL1000ReverseSearchExtract[Gene, Up]'),
#   342),
#  (('GeneSigFromFile', 'UpGeneSetFromSignature'), 331),
#  (('ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_up]',
#    'EnrichrGenesetSearch'),
#   326),
#  (('GMTUnion',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]'),
#   318),
#  (('EnrichrTermSearch[Drug]',
#    'ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]'),
#   308),
#  (('EnrichrTermSearch[Pathway]',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]'),
#   306),
#  (('EnrichrSetTToGMT[Phenotype]', 'GMTConsensus'), 304),
#  (('UpGeneSetFromSignature', 'DownGeneSetFromSignature'), 299),
#  (('FileInput', 'MetadataMatrixFromFile'), 295),
#  (('MetadataMatrixFromFile', 'AnnDataFromGeneCountMatrixAndMetadataMatrix'),
#   292),
#  (('UpGeneSetFromSignature', 'EnrichrGenesetSearch'), 280),
#  (('TermToSet[Term[Gene]]', 'EnrichrGenesetSearch'), 277),
#  (('SigComLINCSGeneSetSearch',
#    'ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]'),
#   270),
#  (('GMTUnion', 'ExtractEnrichrTermSearch[Human_Phenotype_Ontology]'), 265),
#  (('KFTumorExpressionFromGene', 'GTExTissueExpressionFromGene'), 259),
#  (('Input[Variant]', 'VariantInfoFromVariantTerm'), 259),
#  (('ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'EnrichrSetTToGMT[Drug]'),
#   255),
#  (('ExtractEnrichrTermSearch[Human_Phenotype_Ontology]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   248),
#  (('OneScoredT[Scored[Gene]]', 'GeneInfoFromGeneTerm'), 247),
#  (('GMTUnion', 'EnrichrGenesetSearch'), 242),
#  (('LINCSL1000ReverseSearchExtract[Drug, Down]',
#    'LINCSL1000ReverseSearchExtract[Gene, Down]'),
#   241),
#  (('GeneInfoFromGeneTerm', 'GTExTissueExpression'), 235),
#  (('GeneCountMatrixFromFile', 'PCAGraph'), 235),
#  (('ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'EnrichrGenesetSearch'),
#   222),
#  (('PCAGraph', 'FileInput'), 218),
#  (('GeneTermFromVariantTerm', 'Input[Variant]'), 212),
#  (('Input[Disease]', 'EnrichrTermSearch[Disease]'), 210),
#  (('SetFromScored[Scored[Drug]]', 'SetFromScored[Scored[Drug]]'), 210),
#  (('FileInput', 'AnnDataFromFile'), 205),
#  (('GMTUnion', 'EnrichrTermSearch[Drug]'), 201),
#  (('GeneTermFromVariantTerm', 'TermToSet[Term[Gene]]'), 194),
#  (('GTExTissueExpression', 'KFTumorExpression'), 190),
#  (('LINCSL1000ReverseSearchExtract[Gene, Up]',
#    'LINCSL1000ReverseSearchExtract[Drug, Down]'),
#   190),
#  (('Input[Gene]', 'KFTumorExpressionFromGene'), 190),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix', 'Limma-Voom'), 188),
#  (('GeneSigFromFile', 'ScoredGenesFromSignature'), 188),
#  (('EnrichrTermSearch[Disease]',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]'),
#   187),
#  (('MetGeneSearch', 'MetgeneMetabolites'), 187),
#  (('Limma-Voom', 'VolcanoPlot'), 180),
#  (('ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',
#    'ExtractEnrichrTermSearch[KEGG_2021_Human]'),
#   180),
#  (('TargetRangerScreenTargets[GTEx_transcriptomics]',
#    'IDGFilter[Scored[Gene], all]'),
#   179),
#  (('SigComLINCSSignatureSearch',
#    'ExtractSigComLINCSSignatureSearch[LINCS L1000 Chemical Perturbagens]'),
#   178),
#  (('ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'UpGeneSetFromSignature'),
#   176),
#  (('IDGFilter[Scored[Gene], all]', 'OneScoredT[Scored[Gene]]'), 170),
#  (('Input[Gene]', 'GTExTissueExpressionFromGene'), 170),
#  (('ScoredGenesFromSignature', 'SigComLINCSSignatureSearch'), 170),
#  (('ExtractEnrichrTermSearch[KEGG_2021_Human]', 'EnrichrSetTToGMT[Pathway]'),
#   170),
#  (('GeneTermFromVariantTerm', 'Input[Gene]'), 166),
#  (('Input[Phenotype]', 'EnrichrTermSearch[Phenotype]'), 160),
#  (('Input[Gene]', 'TermToSet[Term[Gene]]'), 159),
#  (('KFTumorExpression', 'ProteinProductInformation'), 156),
#  (('GMTConsensus', 'ExtractEnrichrTermSearch[GWAS_Catalog_2019]'), 155),
#  (('ScoredGenesFromSignature', 'ScoredGenesFromSignature'), 153),
#  (('GTExTissueExpressionFromGene', 'KFTumorExpressionFromGene'), 149),
#  (('EnrichrTermSearch[Phenotype]',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]'),
#   147),
#  (('Input[Gene]', 'LINCSL1000ReverseSearch'), 146),
#  (('LINCSL1000ReverseSearchExtract[Gene, Down]',
#    'IDGFilter[Scored[Gene], all]'),
#   144),
#  (('Input[Drug]', 'EnrichrTermSearch[Drug]'), 137),
#  (('Input[Gene]', 'GetRegulatoryElementsForGeneInfoFromGene'), 127),
#  (('ProteinProductInformation', 'EnrichrGeneSearch'), 125),
#  (('EnrichrSetTToGMT[Phenotype]',
#    'ExtractEnrichrTermSearch[GWAS_Catalog_2019]'),
#   121),
#  (('MetgeneMetabolites', 'MetGeneRxns'), 120),
#  (('ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'DownGeneSetFromSignature'),
#   117),
#  (('Input[Gene]', 'EnrichrTermSearch[Gene]'), 116),
#  (('Input[Gene]', 'Input[Gene]'), 115),
#  (('GeneCountMatrixFromFile', 'FileInput'), 113),
#  (('EnrichrGenesetSearch', 'KFTumorExpressionFromGene'), 113),
#  (('Input[Gene]', 'GeneInfoFromGeneTerm'), 112),
#  (('VariantInfoFromVariantTerm', 'GetRegulatoryElementForThisVariant'), 112),
#  (('ExtractEnrichrTermSearch[GWAS_Catalog_2019]',
#    'ExtractEnrichrTermSearch[Human_Phenotype_Ontology]'),
#   110),
#  (('EnrichrSetTToGMT[Drug]', 'EnrichrTermSearch[Drug]'), 106),
#  (('GMTConsensus', 'Input[Drug]'), 103),
#  (('LINCSL1000ReverseSearchExtract[Gene, Down]', 'MetGeneSearch'), 102),
#  (('SigComLINCSGeneSetSearch',
#    'ExtractEnrichrTermSearch[GO_Biological_Process_2021]'),
#   102),
#  (('EnrichrTermSearch[Gene]',
#    'ExtractEnrichrTermSearch[ENCODE_TF_ChIP-seq_2015]'),
#   101),
#  (('IDGFilter[Scored[Gene], all]', 'MetGeneSearch'), 100),
#  (('ExtractEnrichrTermSearch[Human_Phenotype_Ontology]',
#    'ExtractEnrichrTermSearch[ClinVar_2019]'),
#   99),
#  (('VolcanoPlot', 'UpGeneSetFromSignature'), 99),
#  (('Input[Set[Gene]]', 'GeneSet_CTD_String'), 98),
#  (('EnrichrGeneSearch',
#    'ExtractEnrichrGeneSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]'),
#   96),
#  (('Input[Gene]', 'MetGeneSearch'), 95),
#  (('EnrichrGenesetSearch', 'GTExTissueExpressionFromGene'), 93),
#  (('TargetRangerScreenTargets[GTEx_transcriptomics]', 'Input[Gene]'), 92),
#  (('ExtractEnrichrTermSearch[ENCODE_TF_ChIP-seq_2015]',
#    'EnrichrSetTToGMT[Gene]'),
#   90),
#  (('FileInput', 'FileInput'), 89),
#  (('EnrichrSetTToGMT[Drug]', 'GenesetsToGMT'), 88),
#  (('GetRegulatoryElementForThisVariant', 'RegElementInfoFromRegElementTerm'),
#   87),
#  (('ExtractEnrichrTermSearch[ClinVar_2019]', 'EnrichrSetTToGMT[Phenotype]'),
#   85),
#  (('LINCSL1000ReverseSearchExtract[Drug, Down]', 'GeneInfoFromGeneTerm'), 84),
#  (('ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_up]',
#    'SetFromScored[Scored[Drug]]'),
#   84),
#  (('ExtractEnrichrTermSearch[GO_Biological_Process_2021]',
#    'EnrichrSetTToGMT[Pathway]'),
#   84),
#  (('GTExTissueExpressionFromGene', 'BarplotFrom[Scored[Tissue]]'), 81),
#  (('LINCSL1000ReverseSearch', 'GTExTissueExpressionFromGene'), 80),
#  (('GeneTermFromVariantTerm', 'LINCSL1000ReverseSearch'), 79),
#  (('EnrichrSetTToGMT[Gene]', 'ExtractEnrichrTermSearch[ChEA_2022]'), 77),
#  (('ExtractSigComLINCSSignatureSearch[LINCS L1000 Chemical Perturbagens]',
#    'SigComLINCSSignatureSearch'),
#   77),
#  (('GeneSet_CTD_String', 'GeneSet_CTD_Kegg'), 76),
#  (('VariantInfoFromVariantTerm', 'GetAlleleRegistryExternalRecordsForVariant'),
#   75),
#  (('LINCSL1000ReverseSearchExtract[Gene, Up]',
#    'LINCSL1000ReverseSearchExtract[Gene, Down]'),
#   72),
#  (('GeneInfoFromGeneTerm', 'MetgeneMetabolites'), 71),
#  (('ExtractEnrichrGeneSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'ExtractEnrichrGeneSearch[LINCS_L1000_CRISPR_KO_Consensus_Sigs]'),
#   68),
#  (('Input[Gene]', 'ProteinProductInformationFromGene'), 64),
#  (('GeneCountMatrixFromFile', 'MetadataMatrixFromFile'), 64),
#  (('MetgeneMetabolites', 'MetGeneStudies'), 63),
#  (('ExtractEnrichrTermSearch[ChEA_2022]', 'EnrichrSetTToGMT[Gene]'), 63),
#  (('ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'SetFromScored[Scored[Drug]]'),
#   63),
#  (('Input[Variant]', 'Input[Variant]'), 60),
#  (('Input[Set[Gene]]', 'GeneSetIDConv'), 57),
#  (('GenesetsToGMT', 'GMTConcatenate'), 57),
#  (('RegElementInfoFromRegElementTerm', 'GetGenesForRegulatoryElementInfo'),
#   56),
#  (('GeneInfoFromGeneTerm', 'GetRegulatoryElementsForGeneInfo'), 55),
#  (('Input[Set[Variant]]', 'Input[Variant]'), 54),
#  (('GetAlleleRegistryExternalRecordsForVariant', 'Input[Set[Variant]]'), 54),
#  (('LINCSL1000ReverseSearch', 'MetGeneSearch'), 53),
#  (('EnrichrSetTToGMT[Gene]', 'ExtractEnrichrTermSearch[ARCHS4_TFs_Coexp]'),
#   52),
#  (('Input[Regulatory_Element]', 'Input[Gene]'), 52),
#  (('MetGeneStudies', 'MetGeneRxns'), 51),
#  (('LINCSL1000ReverseSearchExtract[Drug, Down]', 'MetGeneSearch'), 51),
#  (('MetGeneRxns', 'GetRegulatoryElementsForGeneInfoFromGene'), 51),
#  (('AnnDataFromFile', 'CDSignatureFromCounts'), 51),
#  (('EnrichrGenesetSearch', 'DownGeneSetFromSignature'), 51),
#  (('LINCSL1000ReverseSearchExtract[Drug, Down]',
#    'LINCSL1000ReverseSearchExtract[Drug, Up]'),
#   50),
#  (('GeneTermFromVariantTerm', 'KFTumorExpressionFromGene'), 49),
#  (('VolcanoPlot', 'ScoredGenesFromSignature'), 48),
#  (('Input[Regulatory_Element]', 'RegElementInfoFromRegElementTerm'), 47),
#  (('GTExTissueExpressionFromGene', 'TopKScoredT[Scored[Tissue]]'), 47),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix', 'CDSignatureFromCounts'),
#   47),
#  (('Input[Set[Gene]]', 'Input[Gene]'), 45),
#  (('GeneTermFromVariantTerm', 'GeneTermFromVariantTerm'), 45),
#  (('ExtractEnrichrGeneSearch[LINCS_L1000_CRISPR_KO_Consensus_Sigs]',
#    'MetGeneRxns'),
#   44),
#  (('Input[Set[Variant]]', 'GetAlleleRegistryExternalRecordsForVariant'), 43),
#  (('ExtractEnrichrTermSearch[ARCHS4_TFs_Coexp]', 'EnrichrSetTToGMT[Gene]'),
#   42),
#  (('GeneSet_CTD_Kegg', 'Highly_Connected_Genes'), 42),
#  (('SetFromScored[Scored[Drug]]', 'DrugSetsToDMT'), 42),
#  (('MetGeneRxns', 'EnrichrGeneSearch'), 41),
#  (('GetRegulatoryElementsForGeneInfoFromGene',
#    'ProteinProductInformationFromGene'),
#   41),
#  (('GetRegulatoryElementsForGeneInfoFromGene', 'KFTumorExpressionFromGene'),
#   41),
#  (('LINCSL1000ReverseSearchExtract[Drug, Up]', 'GTExTissueExpressionFromGene'),
#   41),
#  (('Input[Gene]', 'FetchStringDBPPI'), 41),
#  (('Highly_Connected_Genes', 'Guilty_By_Association_Genes'), 38),
#  (('MetGeneSearch', 'LINCSL1000ReverseSearch'), 37),
#  (('ProteinProductInformationFromGene', 'GTExTissueExpressionFromGene'), 36),
#  (('CDSignatureFromCounts', 'Limma-Voom'), 36),
#  (('FetchStringDBPPI', 'StringDBPPI_to_GraphPlot'), 36),
#  (('Input[Set[Gene]]', 'EnrichrGenesetSearch'), 35),
#  (('ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_down]',
#    'EnrichrSetTToGMT[Drug]'),
#   35),
#  (('GetAlleleRegistryExternalRecordsForVariant', 'Input[Variant]'), 34),
#  (('GTExTissueExpressionFromGene', 'BarplotFrom[[TumorGeneExpression]]'), 34),
#  (('GTExTissueExpressionFromGene', 'OneScoredT[Scored[Tissue]]'), 33),
#  (('RegElementInfoFromRegElementTerm',
#    'GetVariantListForRegulatoryElementInfo'),
#   33),
#  (('Input[Set[Variant]]', 'Input[Set[Variant]]'), 33),
#  (('CDSignatureFromCounts', 'UpGeneSetFromSignature'), 33),
#  (('EnrichrGeneSearch', 'GTExTissueExpression'), 32),
#  (('EnrichrSetTToGMT[Gene]', 'GMTConcatenate'), 32),
#  (('EnrichrTermSearch[Drug]',
#    'ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_up]'),
#   32),
#  (('FileInput', 'GMTFromFile'), 31),
#  (('GetRegulatoryElementsForGeneInfo', 'ProteinProductInformation'), 31),
#  (('GetRegulatoryElementsForGeneInfoFromGene', 'Input[Gene]'), 31),
#  (('KFTumorExpressionFromGene', 'BarplotFrom[[TumorGeneExpression]]'), 31),
#  (('StringDBPPI_to_GraphPlot', 'StringDBPPI_to_GeneSet'), 31),
#  (('MetGeneSearch', 'GetRegulatoryElementsForGeneInfoFromGene'), 30),
#  (('GetGenesForRegulatoryElementInfo',
#    'GetVariantListForRegulatoryElementInfo'),
#   30),
#  (('AnnDataFromFile', 'Limma-Voom'), 29),
#  (('ExtractSigComLINCSSignatureSearch[LINCS L1000 Chemical Perturbagens]',
#    'MeanScoredT[Drug]'),
#   29),
#  (('MetGeneRxns', 'MetGeneStudies'), 28),
#  (('GeneSet_CTD_Kegg', 'GeneSet_CTD_Kegg'), 28),
#  (('VariantInfoFromVariantTerm', 'VariantInfoFromVariantTerm'), 28),
#  (('AnnDataFromFile', 'FileInput'), 28),
#  (('Limma-Voom', 'UpGeneSetFromSignature'), 28),
#  (('Input[Variant]', 'VarinatInfoFromVariantTerm'), 26),
#  (('ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_up]',
#    'ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_down]'),
#   26),
#  (('EnrichrGenesetSearch', 'ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]'),
#   26),
#  (('ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',
#    'ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]'),
#   26),
#  (('BarplotFrom[[TumorGeneExpression]]', 'GTExTissueExpressionFromGene'), 26),
#  (('StringDBPPI_to_GeneSet', 'SigComLINCSGeneSetSearch'), 26),
#  (('GMTConcatenate', 'SupervennFromGMT'), 25),
#  (('KFTumorExpressionFromGene', 'KFTumorExpressionFromGene'), 25),
#  (('GTExTissueExpression', 'ProteinProductInformation'), 24),
#  (('MetGeneSearch', 'MetGeneRxns'), 24),
#  (('ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',
#    'EnrichrTermSearch[Pathway]'),
#   24),
#  (('GeneCountMatrixFromFile', 'AnnDataFromGeneCountMatrixAndMetadataMatrix'),
#   24),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix', 'PCAGraphWithMetadata'), 24),
#  (('Input[Set[Drug]]', 'OneSetT[Set[Drug]]'), 23),
#  (('GMTConcatenate', 'GMTConsensus'), 22),
#  (('GMTConsensus', 'EnrichrGenesetSearch'), 22),
#  (('Input[Gene]', 'Input[Set[Variant]]'), 22),
#  (('Input[Set[Gene]]', 'GeneSet_CTD_Kegg'), 22),
#  (('OneSetT[Set[Drug]]', 'OneSetT[Set[Drug]]'), 22),
#  (('VariantInfoFromVariantTerm', 'Input[Set[Variant]]'), 21),
#  (('SigComLINCSGeneSetSearch', 'EnrichrGenesetSearch'), 21),
#  (('PCAGraphWithMetadata', 'VisualizeLibrarySizesFromAnnData'), 21),
#  (('GeneCountMatrixFromFile', 'TargetRangerScreenTargets[ARCHS4]'), 21),
#  (('CDSignatureFromCounts', 'DownGeneSetFromSignature'), 20),
#  (('MetadataMatrixFromFile', 'FileInput'), 20),
#  (('FileInput', 'Input[Gene]'), 19),
#  (('Guilty_By_Association_Genes', 'Highly_Connected_Genes'), 19),
#  (('GetVariantListForRegulatoryElementInfo',
#    'GetAlleleSpecificEvidencesForThisVariant'),
#   19),
#  (('EnrichrGenesetSearch', 'Input[Pathway]'), 19),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix', 'GeneCountMatrixFromFile'),
#   19),
#  (('GeneTermFromVariantTerm', 'MyVariantInfoFromVariantTerm'), 19),
#  (('LINCSL1000ReverseSearch', 'ProteinProductInformationFromGene'), 18),
#  (('EnrichrGenesetSearch', 'ScoredGenesFromSignature'), 18),
#  (('ProteinProductInformation', 'GetRegulatoryElementsForGeneInfo'), 17),
#  (('MetGeneRxns', 'ProteinProductInformationFromGene'), 17),
#  (('EnrichrTermSearch[Drug]',
#    'ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_down]'),
#   17),
#  (('EnrichrSetTToGMT[Drug]', 'GMTConsensus'), 17),
#  (('Input[Set[Gene]]', 'FileInput'), 17),
#  (('VariantInfoFromVariantTerm', 'Input[Variant]'), 17),
#  (('MyVariantInfoFromVariantTerm', 'VariantInfoFromVariantTerm'), 17),
#  (('EnrichrTermSearch[Pathway]', 'ExtractEnrichrTermSearch[KEGG_2021_Human]'),
#   17),
#  (('TargetRangerScreenTargets[ARCHS4]', 'ARCHS4SignatureSearch[Human]'), 17),
#  (('OneScoredT[Scored[Tissue]]', 'EnrichrTermSearch[Tissue]'), 16),
#  (('EnrichrSetTToGMT[Drug]', 'GMTUnion'), 16),
#  (('DrugSetsToDMT', 'SupervennFromDMT'), 16),
#  (('ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',
#    'MeanScoredT[Drug]'),
#   16),
#  (('EnrichrGenesetSearch', 'MetGeneRxnsSet'), 16),
#  (('MeanScoredT[Drug]', 'FilterFDAApprovedDrugs[Scored[Drug]]'), 15),
#  (('AnnDataFromFile', 'PCAGraphWithMetadata'), 15),
#  (('PCAGraphWithMetadata', 'CDSignatureFromCounts'), 15),
#  (('ProteinProductInformationFromGene', 'MetgeneMetabolites'), 14),
#  (('GeneSetIDConv', 'GeneSet_CTD_Kegg'), 14),
#  (('ProteinProductInformationFromGene', 'KFTumorExpressionFromGene'), 14),
#  (('Input[Set[Variant]]', 'Input[Drug]'), 14),
#  (('VisualizeLibrarySizesFromAnnData', 'LabelAnnDataMetadata'), 14),
#  (('GTExTissueExpressionFromGene', 'GeneInfoFromGeneTerm'), 13),
#  (('Input[Gene]', 'Input[Regulatory_Element]'), 13),
#  (('TopKScoredT[Scored[Tissue]]', 'OneScoredT[Scored[Tissue]]'), 13),
#  (('GetVariantListForRegulatoryElementInfo', 'Input[Regulatory_Element]'), 13),
#  (('GetAlleleSpecificEvidencesForThisVariant',
#    'GetxQTL_EvidencesDataForVariantInfo'),
#   13),
#  (('GetRegulatoryElementsForGeneInfoFromGene',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   13),
#  (('Input[Variant]', 'MyVariantInfoFromVariantTerm'), 13),
#  (('GeneTermFromVariantTerm', 'GTExTissueExpressionFromGene'), 13),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[ENCODE_TF_ChIP-seq_2015]'),
#   13),
#  (('VarinatInfoFromVariantTerm', 'VarinatInfoFromVariantTerm'), 12),
#  (('GTExTissueExpressionFromGene', 'Input[Gene]'), 12),
#  (('ExtractSigComLINCSSignatureSearch[LINCS L1000 Chemical Perturbagens]',
#    'UpGeneSetFromSignature'),
#   12),
#  (('RegElementInfoFromRegElementTerm', 'Input[Variant]'), 12),
#  (('GetRegulatoryElementsForGeneInfo', 'KFTumorExpression'), 11),
#  (('Input[Gene]', 'EnrichrGeneSearch'), 11),
#  (('Input[Metabolite]', 'MetaboliteInfo'), 11),
#  (('GTExTissueExpressionFromGene', 'GTExTissueExpressionFromGene'), 11),
#  (('Input[Gene]', 'acss2 gene'), 11),
#  (('GeneSet_CTD_Kegg', 'CTD_Graph_Nodes'), 11),
#  (('TopKScoredT[Scored[Tissue]]', 'TopKScoredT[Scored[Drug]]'), 11),
#  (('GTExTissueExpressionFromGene', 'BarplotFrom[Scored[Drug]]'), 11),
#  (('GMTUnion', 'EnrichrSetTToGMT[Drug]'), 11),
#  (('UpGeneSetFromSignature', 'UpGeneSetFromSignature'), 11),
#  (('MetGeneRxnsSet', 'MetgeneMetabolitesGeneSet'), 11),
#  (('EnrichrTermSearch[Drug]', 'Input[Set[Drug]]'), 11),
#  (('OneSetT[Set[Drug]]', 'TermToSet[Term[Drug]]'), 11),
#  (('ProteinProductInformation', 'MetgeneMetabolites'), 10),
#  (('LINCSL1000ReverseSearch', 'LINCSL1000ReverseSearchExtract[Gene, Down]'),
#   10),
#  (('LINCSL1000ReverseSearch', 'LINCSL1000ReverseSearchExtract[Drug, Up]'), 10),
#  (('Input[Set[Variant]]', 'Input[Regulatory_Element]'), 10),
#  (('BarplotFrom[Scored[Tissue]]', 'OneScoredT[Scored[Tissue]]'), 10),
#  (('MetGeneSearch', 'MetGeneSearch'), 10),
#  (('GetAlleleRegistryExternalRecordsForVariant',
#    'GetAlleleSpecificEvidencesForThisVariant'),
#   10),
#  (('ARCHS4SignatureSearch[Human]', 'SetFromScored[Scored[Gene]]'), 10),
#  (('Input[Gene]', 'GeneIDConv'), 9),
#  (('MetgeneMetabolites', 'LINCSL1000ReverseSearchExtract[Drug, Up]'), 9),
#  (('VisualizeLibrarySizesFromAnnData', 'CDSignatureFromCounts'), 9),
#  (('Input[Set[Regulatory_Element]]', 'Input[Variant]'), 9),
#  (('SetFromScored[Scored[Gene]]', 'GeneshotGeneSetAugmentation[coexpression]'),
#   9),
#  (('MetadataMatrixFromFile', 'CDSignatureFromCounts'), 8),
#  (('MetGeneStudies', 'MetgeneMetabolites'), 8),
#  (('ProteinProductInformationFromGene',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   8),
#  (('Input[Tissue]', 'EnrichrTermSearch[Tissue]'), 8),
#  (('GMTFromFile', 'SupervennFromGMT'), 8),
#  (('MetGeneSearch', 'Input[Set[Gene]]'), 8),
#  (('GeneSet_CTD_Kegg', 'GeneSet_CTD_String'), 8),
#  (('GMTUnion', 'Input[Drug]'), 8),
#  (('MetGeneRxns', 'MetGeneSearch'), 8),
#  (('ExtractEnrichrGenesetSearch[ENCODE_TF_ChIP-seq_2015]',
#    'ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]'),
#   8),
#  (('ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]',
#    'ExtractEnrichrGenesetSearch[ChEA_2022]'),
#   8),
#  (('GeneTermFromVariantTerm', 'Input[Set[Variant]]'), 8),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'VisualizeLibrarySizesFromAnnData'),
#   8),
#  (('GeneshotGeneSetAugmentation[coexpression]', 'SetFromScored[Scored[Gene]]'),
#   8),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[GTEx_Tissues_V8_2023]'),
#   7),
#  (('Input[Variant]', 'Input[Set[Variant]]'), 7),
#  (('Input[Set[Variant]]', 'Input[Gene]'), 7),
#  (('GeneCountMatrixFromFile', 'LogNormalizeGeneCountMatrix'), 7),
#  (('Input[Set[Gene]]', 'Input[Drug]'), 7),
#  (('TermToSet[Term[Drug]]', 'Input[Set[Variant]]'), 7),
#  (('MetGeneStudies', 'MetGeneSearch'), 7),
#  (('GeneCountMatrixFromFile', 'Transpose'), 7),
#  (('FileInput', 'Input[Phenotype]'), 7),
#  (('SetFromScored[Scored[Gene]]', 'GenesetsToGMT'), 7),
#  (('KFTumorExpression',
#    'ExtractEnrichrGeneSearch[LINCS_L1000_CRISPR_KO_Consensus_Sigs]'),
#   6),
#  (('IDGFilter[Scored[Gene], all]', 'GetRegulatoryElementsForGeneInfoFromGene'),
#   6),
#  (('GeneInfoFromGeneTerm', 'GetRegulatoryElementsForGeneInfoFromGene'), 6),
#  (('OneScoredT[Scored[Tissue]]', 'KFTumorExpressionFromGene'), 6),
#  (('GTExTissueExpressionFromGene', 'GetRegulatoryElementsForGeneInfoFromGene'),
#   6),
#  (('LINCSL1000ReverseSearchExtract[Gene, Down]', 'BarplotFrom[Scored[Gene]]'),
#   6),
#  (('Input[Regulatory_Element]', 'Input[Set[Variant]]'), 6),
#  (('OneScoredT[Scored[Tissue]]', 'OneScoredT[Scored[Tissue]]'), 6),
#  (('CTD_Graph_Nodes', 'CTD_Graph_Nodes'), 6),
#  (('KFTumorExpressionFromGene', 'MetGeneSearch'), 6),
#  (('GeneSetIDConv', 'c1'), 6),
#  (('BarplotFrom[Scored[Drug]]', 'BarplotFrom[Scored[Drug]]'), 6),
#  (('GetRegulatoryElementForThisVariant',
#    'GetAlleleRegistryExternalRecordsForVariant'),
#   6),
#  (('MetgeneMetabolitesGeneSet', 'MetGeneStudiesGeneSet'), 6),
#  (('ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]',
#    'BarplotFrom[Scored[Gene]]'),
#   6),
#  (('Transpose', 'AnnDataFromFile'), 6),
#  (('Input[Phenotype]', 'Input[Tissue]'), 6),
#  (('MetGeneSearch', 'MetGeneStudies'), 6),
#  (('GeneSetIDConv', 'ExtractProteinIDs'), 5),
#  (('LINCSL1000ReverseSearchExtract[Drug, Up]',
#    'LINCSL1000ReverseSearchExtract[Gene, Up]'),
#   5),
#  (('EnrichrGenesetSearch', 'ExtractEnrichrGenesetSearch[ARCHS4_Tissues]'), 5),
#  (('ProteinProductInformationFromGene', 'LINCSL1000ReverseSearch'), 5),
#  (('GetVariantListForRegulatoryElementInfo',
#    'GetGenesForRegulatoryElementInfo'),
#   5),
#  (('KFTumorExpressionFromGene', 'BRCA'), 5),
#  (('Input[Gene]', 'Input[Set[Gene]]'), 5),
#  (('GetRegulatoryElementsForGeneInfoFromGene', 'Input[Set[Variant]]'), 5),
#  (('ExtractEnrichrGenesetSearch[ChEA_2022]', 'DownGeneSetFromSignature'), 5),
#  (('UpGeneSetFromSignature', 'VolcanoPlot'), 5),
#  (('GetGenesForRegulatoryElementInfo', 'IDGFilter[Set[Gene], darkionchannel]'),
#   5),
#  (('GetRegulatoryElementsForGeneInfoFromGene', 'Input[Regulatory_Element]'),
#   5),
#  (('AnnDataFromFile', 'VisualizeLibrarySizes'), 5),
#  (('LabelAnnDataMetadata', 'Limma-Voom'), 5),
#  (('ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]',
#    'BarChartFrom[Scored[Gene]]'),
#   5),
#  (('KFTumorExpressionFromGene', 'VariantInfoFromVariantTerm'), 5),
#  (('ARCHS4SignatureSearch[Human]', 'TopKScoredT[Scored[Gene]]'), 5),
#  (('VarinatInfoFromVariantTerm', 'GetRegulatoryElementsForVariantInfo'), 4),
#  (('Input[Set[Gene]]', 'IDGFilter[Set[Gene], all]'), 4),
#  (('EnrichrTermSearch[Tissue]', 'Input[Disease]'), 4),
#  (('TopKScoredT[Scored[Drug]]', 'TopKScoredT[Scored[Drug]]'), 4),
#  (('GeneSet_CTD_String', 'GeneSet_CTD_String'), 4),
#  (('GetRegulatoryElementsForGeneInfoFromGene', 'Input[Variant]'), 4),
#  (('BarplotFrom[[TumorGeneExpression]]', 'GeneTermFromVariantTerm'), 4),
#  (('ExtractEnrichrGenesetSearch[ENCODE_TF_ChIP-seq_2015]', 'Limma-Voom'), 4),
#  (('IDGFilter[Set[Gene], darkionchannel]', 'IDGFilter[Set[Gene], ionchannel]'),
#   4),
#  (('GetGenesForRegulatoryElementInfo', 'Input[Set[Regulatory_Element]]'), 4),
#  (('AnnDataFromFile', 'LabelAnnDataMetadata'), 4),
#  (('LabelAnnDataMetadata', 'AnnDataFromFile'), 4),
#  (('VariantInfoFromVariantTerm', 'GetAlleleSpecificEvidencesForThisVariant'),
#   4),
#  (('GeneCountMatrixFromFile', 'PCABokehPlotFromGeneCountMatrix'), 3),
#  (('DownGeneSetFromSignature', 'UpGeneSetFromSignature'), 3),
#  (('IDGFilter[Set[Gene], ionchannel]', 'GetGenesForRegulatoryElementInfo'), 3),
#  (('GetxQTL_EvidencesDataForVariantInfo', 'GeneTermFromVariantTerm'), 3),
#  (('VariantInfoFromVariantTerm', 'GeneTermFromVariantTerm'), 3),
#  (('MyVariantInfoFromVariantTerm', 'Input[Variant]'), 3),
#  (('EnrichrGenesetSearch', 'CDSignatureFromCounts'), 3),
#  (('Input[Set[Metabolite]]', 'MetaboliteSetInfo'), 3),
#  (('VisualizeLibrarySizes', 'PCAGraphWithoutMetadata'), 3),
#  (('AnnDataFromFile', 'VisualizeLibrarySizesFromAnnData'), 3),
#  (('VolcanoPlot', 'EnrichrGenesetSearch'), 3),
#  (('Input[Gene]', 'Input[Drug]'), 3),
#  (('GetAlleleSpecificEvidencesForThisVariant',
#    'GetAlleleRegistryExternalRecordsForVariant'),
#   3),
#  (('GeneSetIDConv', 'EnrichrGenesetSearch'), 3),
#  (('TopKScoredT[Scored[Gene]]', 'SetFromScored[Scored[Gene]]'), 3),
#  (('MetgeneMetabolites', 'MGMetTable2MetSet'), 3),
#  (('CDSignatureFromCounts', 'GMTFromSignature'), 2),
#  (('GTExTissueExpression', 'BarplotFrom[Scored[Tissue]]'), 2),
#  (('GeneInfoFromGeneTerm', 'ProteinProductInformation'), 2),
#  (('ExtractProteinIDs', 'GlycosylationsFromProteins'), 2),
#  (('ExtractEnrichrGeneSearch[LINCS_L1000_CRISPR_KO_Consensus_Sigs]',
#    'ExtractEnrichrGeneSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]'),
#   2),
#  (('ProteinProductInformation', 'MetGeneRxns'), 2),
#  (('Input[Gene]', 'MetgeneMetabolites'), 2),
#  (('EnrichrSetTToGMT[Drug]', 'GMTConcatenate'), 2),
#  (('LINCSL1000ReverseSearchExtract[Drug, Down]',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   2),
#  (('MetGeneSearch', 'KFTumorExpressionFromGene'), 2),
#  (('LINCSL1000ReverseSearchExtract[Gene, Up]', 'MetGeneRxns'), 2),
#  (('GetRegulatoryElementsForGeneInfoFromGene', 'IDGFilter[Scored[Gene], all]'),
#   2),
#  (('GetRegulatoryElementsForGeneInfoFromGene', 'GTExTissueExpressionFromGene'),
#   2),
#  (('KFTumorExpressionFromGene', 'Input[Set[Regulatory_Element]]'), 2),
#  (('EnrichrGeneSearch', 'ExtractEnrichrGeneSearch[ARCHS4_TFs_Coexp]'), 2),
#  (('BarplotFrom[Scored[Gene]]', 'MetGeneStudies'), 2),
#  (('KFTumorExpressionFromGene', 'GetRegulatoryElementsForGeneInfoFromGene'),
#   2),
#  (('GeneIDConv', 'ProteinProductInformationFromGene'), 2),
#  (('MetaboliteInfo', 'Input[Set[Variant]]'), 2),
#  (('MetaboliteInfo', 'Input[Variant]'), 2),
#  (('Input[Set[Gene]]', 'IDGFilter[Set[Gene], darkgpcr]'), 2),
#  (('EnrichrTermSearch[Drug]', 'ExtractEnrichrTermSearch[ChEA_2022]'), 2),
#  (('EnrichrSetTToGMT[Drug]', 'GMTIntersection'), 2),
#  (('ExtractEnrichrGenesetSearch[ARCHS4_Tissues]',
#    'BarplotFrom[Scored[Tissue]]'),
#   2),
#  (('VarinatInfoFromVariantTerm', 'FileInput'), 2),
#  (('acss2 gene', 'Input[Set[Gene]]'), 2),
#  (('acss2 gene', 'FileInput'), 2),
#  (('GetRegulatoryElementsForGeneInfoFromGene', 'EnrichrGeneSearch'), 2),
#  (('OneScoredT[Scored[Tissue]]', 'BarplotFrom[Scored[Tissue]]'), 2),
#  (('GeneSetIDConv', 'MetGeneRxnsSet'), 2),
#  (('GeneSetIDConv', 'IDGFilter[Set[Gene], gpcr]'), 2),
#  (('GeneSet_CTD_Kegg', 'GeneSetIDConv'), 2),
#  (('CTD_Graph_Nodes', 'Guilty_By_Association_Genes'), 2),
#  (('TopKScoredT[Scored[Tissue]]', 'BarplotFrom[Scored[Tissue]]'), 2),
#  (('LogNormalizeGeneCountMatrix', 'PCABokehPlotFromGeneCountMatrix'), 2),
#  (('LINCSL1000ReverseSearchExtract[Drug, Up]', 'SetFromScored[Scored[Drug]]'),
#   2),
#  (('GeneInfoFromGeneTerm', 'MetGeneSearch'), 2),
#  (('c1', 'EnrichrSetTToSetT[Pathway]'), 2),
#  (('BarplotFrom[Scored[Drug]]', 'BarplotFrom[Scored[Tissue]]'), 2),
#  (('EnrichrSetTToGMT[Phenotype]', 'GMTConcatenate'), 2),
#  (('GMTConsensus', 'GMTConsensus'), 2),
#  (('GMTConsensus', 'EnrichrTermSearch[Drug]'), 2),
#  (('Input[Set[Gene]]', 'MetGeneRxnsSet'), 2),
#  (('Input[Set[Gene]]', 'MetGeneStudiesGeneSet'), 2),
#  (('KFTumorExpressionFromGene', 'GeneInfoFromGeneTerm'), 2),
#  (('CDSignatureFromCounts', 'CDSignatureFromCounts'), 2),
#  (('DownGeneSetFromSignature', 'DownGeneSetFromSignature'), 2),
#  (('GTExTissueExpressionFromGene', 'MetGeneSearch'), 2),
#  (('GetGenesForRegulatoryElementInfo', 'GeneSet_CTD_Kegg'), 2),
#  (('EnrichrTermSearch[Tissue]',
#    'ExtractEnrichrTermSearch[GO_Biological_Process_2021]'),
#   2),
#  (('BarplotFrom[Scored[Tissue]]', 'MetGeneSearch'), 2),
#  (('BRCA', 'ExtractEnrichrGenesetSearch[WikiPathways_2019_Human]'), 2),
#  (('LINCSL1000ReverseSearchExtract[Drug, Up]',
#    'LINCSL1000ReverseSearchExtract[Drug, Down]'),
#   2),
#  (('EnrichrTermSearch[Disease]',
#    'ExtractEnrichrTermSearch[GTEx_Tissues_V8_2023]'),
#   2),
#  (('CDSignatureFromCounts', 'VolcanoPlot'), 2),
#  (('GeneCountMatrixFromFile', 'VisualizeLibrarySizes'), 2),
#  (('VolcanoPlot', 'VolcanoPlot'), 2),
#  (('MeanScoredT[Drug]', 'UpGeneSetFromSignature'), 2),
#  (('ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',
#    'ExtractEnrichrTermSearch[KEGG_2019_Human]'),
#   2),
#  (('Input[Drug]', 'EnrichrGenesetSearch'), 2),
#  (('EnrichrTermSearch[Pathway]', 'EnrichrGenesetSearch'), 2),
#  (('Input[Set[Regulatory_Element]]', 'Input[Set[Variant]]'), 2),
#  (('Input[Variant]', 'Input[Regulatory_Element]'), 2),
#  (('BarplotFrom[[TumorGeneExpression]]',
#    'ExtractEnrichrGenesetSearch[GTEx_Tissues_V8_2023]'),
#   2),
#  (('BarplotFrom[Scored[Gene]]',
#    'ExtractEnrichrGenesetSearch[GO_Biological_Process_2021]'),
#   2),
#  (('GetGenesForRegulatoryElementInfo', 'Input[Set[Variant]]'), 2),
#  (('Input[Set[Regulatory_Element]]', 'RegElementInfoFromRegElementTerm'), 2),
#  (('MetGeneRxns', 'MetgeneMetabolites'), 2),
#  (('RegElementInfoFromRegElementTerm', 'Input[Set[Regulatory_Element]]'), 2),
#  (('PCAGraphWithoutMetadata', 'PCAGraphWithMetadata'), 2),
#  (('VisualizeLibrarySizesFromAnnData', 'PCAGraphWithMetadata'), 2),
#  (('KFTumorExpressionFromGene', 'GeneIDConv'), 2),
#  (('GetAlleleRegistryExternalRecordsForVariant',
#    'GetRegulatoryElementForThisVariant'),
#   2),
#  (('EnrichrGenesetSearch', 'OneSetT[Set[Gene]]'), 2),
#  (('GetAlleleSpecificEvidencesForThisVariant',
#    'RegElementInfoFromRegElementTerm'),
#   2),
#  (('SetFromScored[Scored[Gene]]', 'SigComLINCSGeneSetSearch'), 2),
#  (('GenesetsToGMT', 'GMTUnion'), 2),
#  (('GenesetsToGMT', 'SupervennFromGMT'), 2),
#  (('MGMetTable2MetSet', 'MetaboliteSetInfo'), 2),
#  (('GeneTermFromVariantTerm', 'GetRegulatoryElementsForGeneInfoFromGene'), 1),
#  (('Input[Set[Drug]]', 'FilterFDAApprovedDrugs[Set[Drug]]'), 1),
#  (('PCAGraph', 'AnnDataFromFile'), 1),
#  (('ExtractEnrichrGenesetSearch[GTEx_Tissues_V8_2023]',
#    'BarplotFrom[Scored[Tissue]]'),
#   1),
#  (('MetadataMatrixFromFile', 'GeneCountMatrixFromFile'), 1),
#  (('ExtractEnrichrGenesetSearch[GO_Biological_Process_2021]',
#    'BarplotFrom[Scored[Pathway]]'),
#   1),
#  (('EnrichrGenesetSearch', 'ExtractEnrichrGenesetSearch[ChEA_2022]'), 1),
#  (('ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]',
#    'ExtractEnrichrGenesetSearch[ARCHS4_Tissues]'),
#   1),
#  (('ExtractEnrichrGenesetSearch[ChEA_2022]',
#    'ExtractEnrichrGenesetSearch[ENCODE_TF_ChIP-seq_2015]'),
#   1),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[GO_Biological_Process_2021]'),
#   1),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix', 'PCAGraph'), 1),
#  (('Input[Set[Variant]]', 'MyVariantInfoFromVariantTerm'), 1),
#  (('FileInput', 'CDSignatureFromCounts'), 1),
#  (('MyVariantInfoFromVariantTerm', 'MyVariantInfoFromVariantTerm'), 1),
#  (('TermToSet[Term[Drug]]', 'FilterFDAApprovedDrugs[Set[Drug]]'), 1),
#  (('Input[Set[Gene]]', 'OneSetT[Set[Gene]]'), 1),
#  (('Input[Set[Regulatory_Element]]', 'Input[Set[Regulatory_Element]]'), 1),
#  (('Input[Disease]', 'Input[Phenotype]'), 1),
#  (('EnrichrTermSearch[Gene]', 'ExtractEnrichrTermSearch[ARCHS4_Tissues]'), 1),
#  (('MetaboliteSetInfo', 'MetaboliteSetInfo'), 1),
#  (('LabelAnnDataMetadata', 'LabelAnnDataMetadata'), 1),
#  (('VisualizeLibrarySizes', 'PCABokehPlotFromGeneCountMatrix'), 1),
#  (('PCAGraphWithMetadata', 'LabelAnnDataMetadata'), 1),
#  (('EnrichrGeneSearch', 'Input[Metabolite]'), 1),
#  (('EnrichrTermSearch[Tissue]', 'EnrichrTermSearch[Tissue]'), 1),
#  (('GeneIDConv', 'GetRegulatoryElementsForGeneInfoFromGene'), 1),
#  (('BarChartFrom[Scored[Gene]]', 'VisualizeLibrarySizesFromAnnData'), 1),
#  (('VisualizeLibrarySizesFromAnnData', 'Limma-Voom'), 1),
#  (('Input[Drug]', 'LINCSL1000ReverseSearch'), 1),
#  (('OneSetT[Set[Gene]]', 'MetGeneSearch'), 1),
#  (('MyVariantInfoFromVariantTerm', 'GeneTermFromMyVariantInfo'), 1),
#  (('RegElementInfoFromRegElementTerm', 'GetxQTL_EvidencesDataForVariantInfo'),
#   1),
#  (('ARCHS4SignatureSearch[Human]', 'SigComLINCSSignatureSearch'), 1),
#  (('SigComLINCSGeneSetSearch', 'BarChartFrom[Scored[Gene]]'), 1),
#  (('GMTUnion', 'SupervennFromGMT'), 1),
#  (('SupervennFromGMT', 'SigComLINCSGeneSetSearch'), 1),
#  (('Input[Set[Gene]]', 'SomeSetT[Set[Gene]]'), 1),
#  (('Input[Set[Gene]]', 'GeneshotGeneSetAugmentation[coexpression]'), 1),
#  (('MetaboliteSetInfo', 'Call_MetENP_on_MetSet'), 1),
#  (('SupervennFromGMT', 'Input[Gene]'), 1),
#  (('MetGeneSearch', 'GTExTissueExpressionFromGene'), 1)]

# %%
grams[3].most_common()
# Out:
# [(('FileInput',
#    'GeneCountMatrixFromFile',
#    'TargetRangerScreenTargets[GTEx_transcriptomics]'),
#   1293),
#  (('GeneCountMatrixFromFile',
#    'TargetRangerScreenTargets[GTEx_transcriptomics]',
#    'OneScoredT[Scored[Gene]]'),
#   963),
#  (('TargetRangerScreenTargets[GTEx_transcriptomics]',
#    'OneScoredT[Scored[Gene]]',
#    'LINCSL1000ReverseSearch'),
#   641),
#  (('FileInput', 'GeneSigFromFile', 'FileInput'), 605),
#  (('ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]',
#    'EnrichrSetTToGMT[Phenotype]',
#    'GMTUnion'),
#   558),
#  (('GeneSigFromFile', 'FileInput', 'GeneSigFromFile'), 546),
#  (('Input[Pathway]',
#    'EnrichrTermSearch[Pathway]',
#    'ExtractEnrichrTermSearch[Human_Phenotype_Ontology]'),
#   463),
#  (('EnrichrTermSearch[Pathway]',
#    'ExtractEnrichrTermSearch[Human_Phenotype_Ontology]',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]'),
#   436),
#  (('ExtractEnrichrTermSearch[Human_Phenotype_Ontology]',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]',
#    'ExtractEnrichrTermSearch[GO_Biological_Process_2021]'),
#   416),
#  (('ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]',
#    'ExtractEnrichrTermSearch[GO_Biological_Process_2021]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   393),
#  (('Input[Phenotype]', 'Input[Drug]', 'Input[Drug]'), 373),
#  (('ExtractEnrichrTermSearch[GO_Biological_Process_2021]',
#    'EnrichrSetTToGMT[Phenotype]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   372),
#  (('Input[Drug]', 'Input[Drug]', 'EnrichrTermSearch[Phenotype]'), 362),
#  (('Input[Drug]',
#    'EnrichrTermSearch[Phenotype]',
#    'ExtractEnrichrTermSearch[GWAS_Catalog_2019]'),
#   354),
#  (('EnrichrSetTToGMT[Phenotype]',
#    'EnrichrSetTToGMT[Phenotype]',
#    'EnrichrSetTToGMT[Pathway]'),
#   351),
#  (('EnrichrTermSearch[Phenotype]',
#    'ExtractEnrichrTermSearch[GWAS_Catalog_2019]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   346),
#  (('OneScoredT[Scored[Gene]]',
#    'LINCSL1000ReverseSearch',
#    'LINCSL1000ReverseSearchExtract[Gene, Up]'),
#   342),
#  (('ExtractEnrichrTermSearch[GWAS_Catalog_2019]',
#    'EnrichrSetTToGMT[Phenotype]',
#    'GMTUnion'),
#   335),
#  (('FileInput', 'GeneSigFromFile', 'UpGeneSetFromSignature'), 331),
#  (('EnrichrSetTToGMT[Phenotype]', 'EnrichrSetTToGMT[Pathway]', 'GMTUnion'),
#   328),
#  (('DownGeneSetFromSignature',
#    'EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]'),
#   328),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_up]',
#    'EnrichrGenesetSearch'),
#   326),
#  (('EnrichrSetTToGMT[Phenotype]',
#    'GMTUnion',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]'),
#   318),
#  (('GMTUnion', 'GMTUnion', 'GMTUnion'), 306),
#  (('Input[Pathway]',
#    'EnrichrTermSearch[Pathway]',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]'),
#   306),
#  (('GMTUnion',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   303),
#  (('EnrichrSetTToGMT[Pathway]', 'GMTUnion', 'GMTUnion'), 301),
#  (('GeneSigFromFile', 'UpGeneSetFromSignature', 'DownGeneSetFromSignature'),
#   293),
#  (('EnrichrTermSearch[Pathway]',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   291),
#  (('OneScoredT[Scored[Gene]]',
#    'LINCSL1000ReverseSearch',
#    'LINCSL1000ReverseSearchExtract[Drug, Down]'),
#   284),
#  (('UpGeneSetFromSignature',
#    'DownGeneSetFromSignature',
#    'EnrichrGenesetSearch'),
#   274),
#  (('ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_up]',
#    'EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_up]'),
#   273),
#  (('GMTUnion',
#    'SigComLINCSGeneSetSearch',
#    'ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]'),
#   270),
#  (('EnrichrSetTToGMT[Phenotype]',
#    'GMTUnion',
#    'ExtractEnrichrTermSearch[Human_Phenotype_Ontology]'),
#   265),
#  (('EnrichrTermSearch[Drug]',
#    'ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'EnrichrSetTToGMT[Drug]'),
#   255),
#  (('EnrichrSetTToGMT[Phenotype]', 'GMTUnion', 'SigComLINCSGeneSetSearch'),
#   255),
#  (('TargetRangerScreenTargets[GTEx_transcriptomics]',
#    'OneScoredT[Scored[Gene]]',
#    'GeneInfoFromGeneTerm'),
#   247),
#  (('GMTUnion',
#    'ExtractEnrichrTermSearch[Human_Phenotype_Ontology]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   243),
#  (('GMTUnion', 'GMTUnion', 'EnrichrGenesetSearch'), 242),
#  (('LINCSL1000ReverseSearch',
#    'LINCSL1000ReverseSearchExtract[Drug, Down]',
#    'LINCSL1000ReverseSearchExtract[Gene, Down]'),
#   241),
#  (('FileInput',
#    'MetadataMatrixFromFile',
#    'AnnDataFromGeneCountMatrixAndMetadataMatrix'),
#   240),
#  (('FileInput', 'GeneCountMatrixFromFile', 'PCAGraph'), 235),
#  (('OneScoredT[Scored[Gene]]', 'GeneInfoFromGeneTerm', 'GTExTissueExpression'),
#   226),
#  (('ExtractEnrichrTermSearch[Human_Phenotype_Ontology]',
#    'EnrichrSetTToGMT[Phenotype]',
#    'GMTUnion'),
#   223),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'EnrichrGenesetSearch'),
#   222),
#  (('GeneCountMatrixFromFile', 'PCAGraph', 'FileInput'), 218),
#  (('GMTUnion',
#    'EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_up]'),
#   215),
#  (('Input[Variant]', 'GeneTermFromVariantTerm', 'Input[Variant]'), 212),
#  (('PCAGraph', 'FileInput', 'MetadataMatrixFromFile'), 205),
#  (('EnrichrSetTToGMT[Phenotype]', 'GMTUnion', 'EnrichrTermSearch[Drug]'), 201),
#  (('ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]'),
#   200),
#  (('GeneInfoFromGeneTerm', 'GTExTissueExpression', 'KFTumorExpression'), 190),
#  (('LINCSL1000ReverseSearch',
#    'LINCSL1000ReverseSearchExtract[Gene, Up]',
#    'LINCSL1000ReverseSearchExtract[Drug, Down]'),
#   190),
#  (('FileInput', 'GeneSigFromFile', 'ScoredGenesFromSignature'), 188),
#  (('Input[Disease]',
#    'EnrichrTermSearch[Disease]',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]'),
#   187),
#  (('GeneTermFromVariantTerm', 'Input[Variant]', 'GeneTermFromVariantTerm'),
#   186),
#  (('MetadataMatrixFromFile',
#    'AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'Limma-Voom'),
#   182),
#  (('EnrichrTermSearch[Disease]',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   180),
#  (('SigComLINCSGeneSetSearch',
#    'ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',
#    'ExtractEnrichrTermSearch[KEGG_2021_Human]'),
#   180),
#  (('ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]',
#    'EnrichrSetTToGMT[Phenotype]',
#    'GMTConsensus'),
#   179),
#  (('GeneCountMatrixFromFile',
#    'TargetRangerScreenTargets[GTEx_transcriptomics]',
#    'IDGFilter[Scored[Gene], all]'),
#   179),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'UpGeneSetFromSignature'),
#   176),
#  (('EnrichrSetTToGMT[Pathway]', 'GMTUnion', 'SigComLINCSGeneSetSearch'), 174),
#  (('TargetRangerScreenTargets[GTEx_transcriptomics]',
#    'IDGFilter[Scored[Gene], all]',
#    'OneScoredT[Scored[Gene]]'),
#   170),
#  (('Input[Variant]', 'GeneTermFromVariantTerm', 'Input[Gene]'), 166),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix', 'Limma-Voom', 'VolcanoPlot'),
#   160),
#  (('ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',
#    'ExtractEnrichrTermSearch[KEGG_2021_Human]',
#    'EnrichrSetTToGMT[Pathway]'),
#   159),
#  (('GTExTissueExpression', 'KFTumorExpression', 'ProteinProductInformation'),
#   156),
#  (('ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'UpGeneSetFromSignature',
#    'EnrichrGenesetSearch'),
#   156),
#  (('EnrichrSetTToGMT[Phenotype]',
#    'GMTConsensus',
#    'ExtractEnrichrTermSearch[GWAS_Catalog_2019]'),
#   155),
#  (('Input[Variant]', 'GeneTermFromVariantTerm', 'TermToSet[Term[Gene]]'), 154),
#  (('GeneSigFromFile', 'ScoredGenesFromSignature', 'ScoredGenesFromSignature'),
#   153),
#  (('GeneTermFromVariantTerm', 'TermToSet[Term[Gene]]', 'EnrichrGenesetSearch'),
#   152),
#  (('IDGFilter[Scored[Gene], all]',
#    'OneScoredT[Scored[Gene]]',
#    'LINCSL1000ReverseSearch'),
#   151),
#  (('Input[Phenotype]',
#    'EnrichrTermSearch[Phenotype]',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]'),
#   147),
#  (('ExtractEnrichrTermSearch[KEGG_2021_Human]',
#    'EnrichrSetTToGMT[Pathway]',
#    'GMTUnion'),
#   145),
#  (('LINCSL1000ReverseSearchExtract[Drug, Down]',
#    'LINCSL1000ReverseSearchExtract[Gene, Down]',
#    'IDGFilter[Scored[Gene], all]'),
#   144),
#  (('GMTUnion',
#    'EnrichrTermSearch[Drug]',
#    'ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]'),
#   143),
#  (('EnrichrTermSearch[Phenotype]',
#    'ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   140),
#  (('GMTConsensus',
#    'ExtractEnrichrTermSearch[GWAS_Catalog_2019]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   137),
#  (('UpGeneSetFromSignature',
#    'EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]'),
#   136),
#  (('GeneTermFromVariantTerm', 'Input[Gene]', 'TermToSet[Term[Gene]]'), 131),
#  (('ScoredGenesFromSignature',
#    'ScoredGenesFromSignature',
#    'SigComLINCSSignatureSearch'),
#   128),
#  (('KFTumorExpression', 'ProteinProductInformation', 'EnrichrGeneSearch'),
#   125),
#  (('Input[Gene]', 'TermToSet[Term[Gene]]', 'EnrichrGenesetSearch'), 125),
#  (('ScoredGenesFromSignature',
#    'SigComLINCSSignatureSearch',
#    'ExtractSigComLINCSSignatureSearch[LINCS L1000 Chemical Perturbagens]'),
#   124),
#  (('ExtractEnrichrTermSearch[MGI_Mammalian_Phenotype_Level_4_2019]',
#    'EnrichrSetTToGMT[Phenotype]',
#    'ExtractEnrichrTermSearch[GWAS_Catalog_2019]'),
#   121),
#  (('MetGeneSearch', 'MetgeneMetabolites', 'MetGeneRxns'), 120),
#  (('ExtractEnrichrTermSearch[GWAS_Catalog_2019]',
#    'EnrichrSetTToGMT[Phenotype]',
#    'GMTConsensus'),
#   119),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'DownGeneSetFromSignature'),
#   117),
#  (('FileInput', 'GeneCountMatrixFromFile', 'FileInput'), 113),
#  (('TermToSet[Term[Gene]]',
#    'EnrichrGenesetSearch',
#    'KFTumorExpressionFromGene'),
#   113),
#  (('EnrichrSetTToGMT[Phenotype]',
#    'ExtractEnrichrTermSearch[GWAS_Catalog_2019]',
#    'ExtractEnrichrTermSearch[Human_Phenotype_Ontology]'),
#   110),
#  (('Input[Variant]',
#    'VariantInfoFromVariantTerm',
#    'GetRegulatoryElementForThisVariant'),
#   106),
#  (('ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'EnrichrSetTToGMT[Drug]',
#    'EnrichrTermSearch[Drug]'),
#   106),
#  (('EnrichrSetTToGMT[Phenotype]', 'GMTConsensus', 'Input[Drug]'), 103),
#  (('GMTUnion',
#    'SigComLINCSGeneSetSearch',
#    'ExtractEnrichrTermSearch[GO_Biological_Process_2021]'),
#   102),
#  (('Input[Gene]',
#    'EnrichrTermSearch[Gene]',
#    'ExtractEnrichrTermSearch[ENCODE_TF_ChIP-seq_2015]'),
#   101),
#  (('SetFromScored[Scored[Drug]]',
#    'SetFromScored[Scored[Drug]]',
#    'SetFromScored[Scored[Drug]]'),
#   101),
#  (('LINCSL1000ReverseSearchExtract[Gene, Down]',
#    'IDGFilter[Scored[Gene], all]',
#    'MetGeneSearch'),
#   100),
#  (('ExtractEnrichrTermSearch[GWAS_Catalog_2019]',
#    'ExtractEnrichrTermSearch[Human_Phenotype_Ontology]',
#    'ExtractEnrichrTermSearch[ClinVar_2019]'),
#   99),
#  (('Limma-Voom', 'VolcanoPlot', 'UpGeneSetFromSignature'), 99),
#  (('ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'DownGeneSetFromSignature',
#    'EnrichrGenesetSearch'),
#   98),
#  (('ProteinProductInformation',
#    'EnrichrGeneSearch',
#    'ExtractEnrichrGeneSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]'),
#   96),
#  (('TermToSet[Term[Gene]]',
#    'EnrichrGenesetSearch',
#    'GTExTissueExpressionFromGene'),
#   93),
#  (('GeneCountMatrixFromFile',
#    'TargetRangerScreenTargets[GTEx_transcriptomics]',
#    'Input[Gene]'),
#   92),
#  (('EnrichrTermSearch[Gene]',
#    'ExtractEnrichrTermSearch[ENCODE_TF_ChIP-seq_2015]',
#    'EnrichrSetTToGMT[Gene]'),
#   90),
#  (('ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'EnrichrSetTToGMT[Drug]',
#    'GenesetsToGMT'),
#   88),
#  (('VariantInfoFromVariantTerm',
#    'GetRegulatoryElementForThisVariant',
#    'RegElementInfoFromRegElementTerm'),
#   86),
#  (('EnrichrSetTToGMT[Drug]',
#    'EnrichrTermSearch[Drug]',
#    'ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]'),
#   86),
#  (('ExtractEnrichrTermSearch[Human_Phenotype_Ontology]',
#    'ExtractEnrichrTermSearch[ClinVar_2019]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   85),
#  (('LINCSL1000ReverseSearchExtract[Gene, Up]',
#    'LINCSL1000ReverseSearchExtract[Drug, Down]',
#    'GeneInfoFromGeneTerm'),
#   84),
#  (('GMTConsensus', 'Input[Drug]', 'EnrichrTermSearch[Drug]'), 84),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_up]',
#    'SetFromScored[Scored[Drug]]'),
#   84),
#  (('SigComLINCSGeneSetSearch',
#    'ExtractEnrichrTermSearch[GO_Biological_Process_2021]',
#    'EnrichrSetTToGMT[Pathway]'),
#   84),
#  (('TargetRangerScreenTargets[GTEx_transcriptomics]',
#    'Input[Gene]',
#    'GeneInfoFromGeneTerm'),
#   81),
#  (('Input[Drug]',
#    'EnrichrTermSearch[Drug]',
#    'ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]'),
#   79),
#  (('Input[Gene]', 'KFTumorExpressionFromGene', 'GTExTissueExpressionFromGene'),
#   79),
#  (('Input[Variant]', 'GeneTermFromVariantTerm', 'LINCSL1000ReverseSearch'),
#   79),
#  (('EnrichrGenesetSearch',
#    'KFTumorExpressionFromGene',
#    'GTExTissueExpressionFromGene'),
#   79),
#  (('ExtractEnrichrTermSearch[ENCODE_TF_ChIP-seq_2015]',
#    'EnrichrSetTToGMT[Gene]',
#    'ExtractEnrichrTermSearch[ChEA_2022]'),
#   77),
#  (('SigComLINCSSignatureSearch',
#    'ExtractSigComLINCSSignatureSearch[LINCS L1000 Chemical Perturbagens]',
#    'SigComLINCSSignatureSearch'),
#   77),
#  (('Input[Set[Gene]]', 'GeneSet_CTD_String', 'GeneSet_CTD_Kegg'), 76),
#  (('VolcanoPlot', 'UpGeneSetFromSignature', 'EnrichrGenesetSearch'), 76),
#  (('LINCSL1000ReverseSearchExtract[Gene, Down]',
#    'MetGeneSearch',
#    'MetgeneMetabolites'),
#   73),
#  (('GeneCountMatrixFromFile', 'FileInput', 'MetadataMatrixFromFile'), 72),
#  (('LINCSL1000ReverseSearch',
#    'LINCSL1000ReverseSearchExtract[Gene, Up]',
#    'LINCSL1000ReverseSearchExtract[Gene, Down]'),
#   72),
#  (('IDGFilter[Scored[Gene], all]', 'MetGeneSearch', 'MetgeneMetabolites'), 72),
#  (('Input[Gene]', 'GeneInfoFromGeneTerm', 'MetgeneMetabolites'), 71),
#  (('ExtractEnrichrTermSearch[ClinVar_2019]',
#    'EnrichrSetTToGMT[Phenotype]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   71),
#  (('EnrichrGeneSearch',
#    'ExtractEnrichrGeneSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'ExtractEnrichrGeneSearch[LINCS_L1000_CRISPR_KO_Consensus_Sigs]'),
#   68),
#  (('ExtractEnrichrTermSearch[GO_Biological_Process_2021]',
#    'EnrichrSetTToGMT[Pathway]',
#    'GMTUnion'),
#   67),
#  (('EnrichrGenesetSearch',
#    'GTExTissueExpressionFromGene',
#    'KFTumorExpressionFromGene'),
#   65),
#  (('FileInput', 'GeneCountMatrixFromFile', 'MetadataMatrixFromFile'), 64),
#  (('Input[Variant]',
#    'VariantInfoFromVariantTerm',
#    'GetAlleleRegistryExternalRecordsForVariant'),
#   64),
#  (('FileInput', 'FileInput', 'GeneCountMatrixFromFile'), 64),
#  (('EnrichrSetTToGMT[Gene]',
#    'ExtractEnrichrTermSearch[ChEA_2022]',
#    'EnrichrSetTToGMT[Gene]'),
#   63),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'SetFromScored[Scored[Drug]]'),
#   63),
#  (('ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_up]',
#    'SetFromScored[Scored[Drug]]',
#    'SetFromScored[Scored[Drug]]'),
#   62),
#  (('GeneInfoFromGeneTerm', 'MetgeneMetabolites', 'MetGeneStudies'), 61),
#  (('Input[Gene]',
#    'LINCSL1000ReverseSearch',
#    'LINCSL1000ReverseSearchExtract[Drug, Down]'),
#   58),
#  (('EnrichrSetTToGMT[Phenotype]',
#    'EnrichrSetTToGMT[Phenotype]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   58),
#  (('EnrichrSetTToGMT[Drug]', 'GenesetsToGMT', 'GMTConcatenate'), 57),
#  (('Input[Gene]', 'Input[Gene]', 'KFTumorExpressionFromGene'), 56),
#  (('LINCSL1000ReverseSearchExtract[Drug, Down]',
#    'GeneInfoFromGeneTerm',
#    'GetRegulatoryElementsForGeneInfo'),
#   55),
#  (('Input[Variant]', 'Input[Variant]', 'GeneTermFromVariantTerm'), 55),
#  (('LINCSL1000ReverseSearchExtract[Gene, Up]',
#    'LINCSL1000ReverseSearchExtract[Gene, Down]',
#    'MetGeneSearch'),
#   54),
#  (('VariantInfoFromVariantTerm',
#    'GetAlleleRegistryExternalRecordsForVariant',
#    'Input[Set[Variant]]'),
#   54),
#  (('ExtractSigComLINCSSignatureSearch[LINCS L1000 Chemical Perturbagens]',
#    'SigComLINCSSignatureSearch',
#    'ExtractSigComLINCSSignatureSearch[LINCS L1000 Chemical Perturbagens]'),
#   54),
#  (('ExtractEnrichrTermSearch[ChEA_2022]',
#    'EnrichrSetTToGMT[Gene]',
#    'ExtractEnrichrTermSearch[ARCHS4_TFs_Coexp]'),
#   52),
#  (('KFTumorExpressionFromGene',
#    'GTExTissueExpressionFromGene',
#    'KFTumorExpressionFromGene'),
#   52),
#  (('GeneTermFromVariantTerm',
#    'LINCSL1000ReverseSearch',
#    'GTExTissueExpressionFromGene'),
#   52),
#  (('GeneCountMatrixFromFile',
#    'MetadataMatrixFromFile',
#    'AnnDataFromGeneCountMatrixAndMetadataMatrix'),
#   52),
#  (('MetgeneMetabolites', 'MetGeneStudies', 'MetGeneRxns'), 51),
#  (('LINCSL1000ReverseSearchExtract[Gene, Up]',
#    'LINCSL1000ReverseSearchExtract[Drug, Down]',
#    'MetGeneSearch'),
#   51),
#  (('MetgeneMetabolites',
#    'MetGeneRxns',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   51),
#  (('UpGeneSetFromSignature',
#    'EnrichrGenesetSearch',
#    'DownGeneSetFromSignature'),
#   51),
#  (('LINCSL1000ReverseSearch',
#    'LINCSL1000ReverseSearchExtract[Drug, Down]',
#    'LINCSL1000ReverseSearchExtract[Drug, Up]'),
#   50),
#  (('FileInput', 'AnnDataFromFile', 'CDSignatureFromCounts'), 50),
#  (('OneScoredT[Scored[Gene]]', 'LINCSL1000ReverseSearch', 'MetGeneSearch'),
#   49),
#  (('GetRegulatoryElementForThisVariant',
#    'RegElementInfoFromRegElementTerm',
#    'GetGenesForRegulatoryElementInfo'),
#   49),
#  (('Input[Variant]', 'GeneTermFromVariantTerm', 'KFTumorExpressionFromGene'),
#   49),
#  (('LINCSL1000ReverseSearchExtract[Drug, Down]',
#    'LINCSL1000ReverseSearchExtract[Gene, Down]',
#    'MetGeneSearch'),
#   48),
#  (('Limma-Voom', 'VolcanoPlot', 'ScoredGenesFromSignature'), 48),
#  (('ExtractEnrichrGenesetSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'SetFromScored[Scored[Drug]]',
#    'SetFromScored[Scored[Drug]]'),
#   47),
#  (('ExtractEnrichrGeneSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'ExtractEnrichrGeneSearch[LINCS_L1000_CRISPR_KO_Consensus_Sigs]',
#    'MetGeneRxns'),
#   44),
#  (('Input[Variant]', 'GeneTermFromVariantTerm', 'GeneTermFromVariantTerm'),
#   44),
#  (('GetAlleleRegistryExternalRecordsForVariant',
#    'Input[Set[Variant]]',
#    'GetAlleleRegistryExternalRecordsForVariant'),
#   43),
#  (('EnrichrSetTToGMT[Gene]',
#    'ExtractEnrichrTermSearch[ARCHS4_TFs_Coexp]',
#    'EnrichrSetTToGMT[Gene]'),
#   42),
#  (('GeneSet_CTD_String', 'GeneSet_CTD_Kegg', 'Highly_Connected_Genes'), 42),
#  (('SetFromScored[Scored[Drug]]',
#    'SetFromScored[Scored[Drug]]',
#    'DrugSetsToDMT'),
#   42),
#  (('MetGeneStudies', 'MetGeneRxns', 'EnrichrGeneSearch'), 41),
#  (('LINCSL1000ReverseSearchExtract[Drug, Down]',
#    'LINCSL1000ReverseSearchExtract[Drug, Up]',
#    'GTExTissueExpressionFromGene'),
#   41),
#  (('GTExTissueExpressionFromGene',
#    'KFTumorExpressionFromGene',
#    'GTExTissueExpressionFromGene'),
#   41),
#  (('GeneTermFromVariantTerm',
#    'GeneTermFromVariantTerm',
#    'TermToSet[Term[Gene]]'),
#   40),
#  (('Input[Gene]',
#    'GetRegulatoryElementsForGeneInfoFromGene',
#    'KFTumorExpressionFromGene'),
#   39),
#  (('Input[Regulatory_Element]',
#    'Input[Gene]',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   38),
#  (('EnrichrSetTToGMT[Phenotype]', 'EnrichrSetTToGMT[Phenotype]', 'GMTUnion'),
#   38),
#  (('LINCSL1000ReverseSearch',
#    'GTExTissueExpressionFromGene',
#    'BarplotFrom[Scored[Tissue]]'),
#   38),
#  (('Input[Gene]', 'FetchStringDBPPI', 'StringDBPPI_to_GraphPlot'), 36),
#  (('Input[Gene]', 'MetGeneSearch', 'LINCSL1000ReverseSearch'), 35),
#  (('LINCSL1000ReverseSearchExtract[Drug, Down]',
#    'MetGeneSearch',
#    'MetgeneMetabolites'),
#   34),
#  (('Input[Set[Variant]]',
#    'GetAlleleRegistryExternalRecordsForVariant',
#    'Input[Variant]'),
#   34),
#  (('VolcanoPlot', 'ScoredGenesFromSignature', 'SigComLINCSSignatureSearch'),
#   34),
#  (('KFTumorExpressionFromGene',
#    'GTExTissueExpressionFromGene',
#    'BarplotFrom[[TumorGeneExpression]]'),
#   34),
#  (('Input[Gene]',
#    'GTExTissueExpressionFromGene',
#    'OneScoredT[Scored[Tissue]]'),
#   33),
#  (('EnrichrGenesetSearch', 'DownGeneSetFromSignature', 'EnrichrGenesetSearch'),
#   33),
#  (('MetGeneRxns', 'EnrichrGeneSearch', 'GTExTissueExpression'), 32),
#  (('ExtractEnrichrTermSearch[ARCHS4_TFs_Coexp]',
#    'EnrichrSetTToGMT[Gene]',
#    'GMTConcatenate'),
#   32),
#  (('GMTUnion',
#    'EnrichrTermSearch[Drug]',
#    'ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_up]'),
#   32),
#  (('GeneInfoFromGeneTerm',
#    'GetRegulatoryElementsForGeneInfo',
#    'ProteinProductInformation'),
#   31),
#  (('Input[Gene]',
#    'GTExTissueExpressionFromGene',
#    'BarplotFrom[Scored[Tissue]]'),
#   31),
#  (('GTExTissueExpressionFromGene',
#    'KFTumorExpressionFromGene',
#    'BarplotFrom[[TumorGeneExpression]]'),
#   31),
#  (('FetchStringDBPPI', 'StringDBPPI_to_GraphPlot', 'StringDBPPI_to_GeneSet'),
#   31),
#  (('MetadataMatrixFromFile',
#    'AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'CDSignatureFromCounts'),
#   31),
#  (('LINCSL1000ReverseSearch',
#    'MetGeneSearch',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   30),
#  (('GeneSet_CTD_Kegg',
#    'Highly_Connected_Genes',
#    'Guilty_By_Association_Genes'),
#   30),
#  (('RegElementInfoFromRegElementTerm',
#    'GetGenesForRegulatoryElementInfo',
#    'GetVariantListForRegulatoryElementInfo'),
#   30),
#  (('EnrichrSetTToGMT[Phenotype]', 'GMTUnion', 'GMTUnion'), 29),
#  (('FileInput', 'AnnDataFromFile', 'Limma-Voom'), 29),
#  (('SigComLINCSSignatureSearch',
#    'ExtractSigComLINCSSignatureSearch[LINCS L1000 Chemical Perturbagens]',
#    'MeanScoredT[Drug]'),
#   29),
#  (('Input[Variant]',
#    'VariantInfoFromVariantTerm',
#    'VariantInfoFromVariantTerm'),
#   28),
#  (('Input[Gene]', 'Input[Gene]', 'TermToSet[Term[Gene]]'), 28),
#  (('FileInput', 'AnnDataFromFile', 'FileInput'), 28),
#  (('Input[Gene]', 'LINCSL1000ReverseSearch', 'GTExTissueExpressionFromGene'),
#   28),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'CDSignatureFromCounts',
#    'UpGeneSetFromSignature'),
#   27),
#  (('CDSignatureFromCounts', 'UpGeneSetFromSignature', 'EnrichrGenesetSearch'),
#   27),
#  (('EnrichrTermSearch[Drug]',
#    'ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_up]',
#    'ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_down]'),
#   26),
#  (('Input[Set[Gene]]',
#    'Input[Gene]',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   26),
#  (('SigComLINCSGeneSetSearch',
#    'ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',
#    'ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]'),
#   26),
#  (('StringDBPPI_to_GraphPlot',
#    'StringDBPPI_to_GeneSet',
#    'SigComLINCSGeneSetSearch'),
#   26),
#  (('GenesetsToGMT', 'GMTConcatenate', 'SupervennFromGMT'), 25),
#  (('Input[Gene]',
#    'ProteinProductInformationFromGene',
#    'GTExTissueExpressionFromGene'),
#   25),
#  (('Input[Gene]', 'KFTumorExpressionFromGene', 'KFTumorExpressionFromGene'),
#   25),
#  (('GeneTermFromVariantTerm',
#    'KFTumorExpressionFromGene',
#    'GTExTissueExpressionFromGene'),
#   25),
#  (('EnrichrGeneSearch', 'GTExTissueExpression', 'ProteinProductInformation'),
#   24),
#  (('ExtractEnrichrGeneSearch[LINCS_L1000_CRISPR_KO_Consensus_Sigs]',
#    'MetGeneRxns',
#    'MetGeneStudies'),
#   24),
#  (('Input[Set[Variant]]', 'Input[Set[Variant]]', 'Input[Variant]'), 24),
#  (('GetAlleleRegistryExternalRecordsForVariant',
#    'Input[Variant]',
#    'VariantInfoFromVariantTerm'),
#   24),
#  (('SigComLINCSGeneSetSearch',
#    'ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',
#    'EnrichrTermSearch[Pathway]'),
#   24),
#  (('MetadataMatrixFromFile',
#    'AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'PCAGraphWithMetadata'),
#   24),
#  (('GetRegulatoryElementsForGeneInfoFromGene',
#    'KFTumorExpressionFromGene',
#    'GTExTissueExpressionFromGene'),
#   23),
#  (('Input[Gene]', 'GetRegulatoryElementsForGeneInfoFromGene', 'Input[Gene]'),
#   23),
#  (('EnrichrSetTToGMT[Gene]', 'GMTConcatenate', 'GMTConsensus'), 22),
#  (('MetGeneSearch',
#    'GetRegulatoryElementsForGeneInfoFromGene',
#    'ProteinProductInformationFromGene'),
#   21),
#  (('ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_up]',
#    'ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_down]',
#    'EnrichrSetTToGMT[Drug]'),
#   21),
#  (('StringDBPPI_to_GeneSet',
#    'SigComLINCSGeneSetSearch',
#    'EnrichrGenesetSearch'),
#   21),
#  (('FileInput',
#    'GeneCountMatrixFromFile',
#    'TargetRangerScreenTargets[ARCHS4]'),
#   21),
#  (('ProteinProductInformationFromGene',
#    'GTExTissueExpressionFromGene',
#    'TopKScoredT[Scored[Tissue]]'),
#   20),
#  (('GetRegulatoryElementForThisVariant',
#    'RegElementInfoFromRegElementTerm',
#    'GetVariantListForRegulatoryElementInfo'),
#   20),
#  (('FileInput', 'MetadataMatrixFromFile', 'FileInput'), 20),
#  (('LINCSL1000ReverseSearchExtract[Drug, Up]',
#    'GTExTissueExpressionFromGene',
#    'TopKScoredT[Scored[Tissue]]'),
#   19),
#  (('Highly_Connected_Genes',
#    'Guilty_By_Association_Genes',
#    'Highly_Connected_Genes'),
#   19),
#  (('GetGenesForRegulatoryElementInfo',
#    'GetVariantListForRegulatoryElementInfo',
#    'GetAlleleSpecificEvidencesForThisVariant'),
#   19),
#  (('Input[Set[Variant]]', 'Input[Variant]', 'VariantInfoFromVariantTerm'), 19),
#  (('Input[Set[Gene]]', 'EnrichrGenesetSearch', 'Input[Pathway]'), 19),
#  (('MetadataMatrixFromFile',
#    'AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'GeneCountMatrixFromFile'),
#   19),
#  (('MetGeneRxns',
#    'GetRegulatoryElementsForGeneInfoFromGene',
#    'ProteinProductInformationFromGene'),
#   18),
#  (('DownGeneSetFromSignature',
#    'EnrichrGenesetSearch',
#    'ScoredGenesFromSignature'),
#   18),
#  (('BarplotFrom[[TumorGeneExpression]]',
#    'GTExTissueExpressionFromGene',
#    'KFTumorExpressionFromGene'),
#   18),
#  (('GTExTissueExpression',
#    'ProteinProductInformation',
#    'GetRegulatoryElementsForGeneInfo'),
#   17),
#  (('MetgeneMetabolites', 'MetGeneRxns', 'ProteinProductInformationFromGene'),
#   17),
#  (('MetGeneSearch',
#    'LINCSL1000ReverseSearch',
#    'ProteinProductInformationFromGene'),
#   17),
#  (('Input[Drug]',
#    'EnrichrTermSearch[Drug]',
#    'ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_down]'),
#   17),
#  (('GeneSet_CTD_String', 'GeneSet_CTD_Kegg', 'GeneSet_CTD_Kegg'), 17),
#  (('Input[Variant]', 'VariantInfoFromVariantTerm', 'Input[Variant]'), 17),
#  (('GeneTermFromVariantTerm', 'Input[Gene]', 'KFTumorExpressionFromGene'), 17),
#  (('ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',
#    'EnrichrTermSearch[Pathway]',
#    'ExtractEnrichrTermSearch[KEGG_2021_Human]'),
#   17),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'GeneCountMatrixFromFile',
#    'AnnDataFromGeneCountMatrixAndMetadataMatrix'),
#   17),
#  (('Input[Variant]',
#    'GeneTermFromVariantTerm',
#    'MyVariantInfoFromVariantTerm'),
#   17),
#  (('VariantInfoFromVariantTerm',
#    'VariantInfoFromVariantTerm',
#    'Input[Set[Variant]]'),
#   17),
#  (('Input[Set[Drug]]', 'OneSetT[Set[Drug]]', 'OneSetT[Set[Drug]]'), 17),
#  (('GeneCountMatrixFromFile',
#    'TargetRangerScreenTargets[ARCHS4]',
#    'ARCHS4SignatureSearch[Human]'),
#   17),
#  (('Input[Gene]', 'Input[Set[Variant]]', 'Input[Variant]'), 16),
#  (('ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_down]',
#    'EnrichrSetTToGMT[Drug]',
#    'GMTUnion'),
#   16),
#  (('SetFromScored[Scored[Drug]]', 'DrugSetsToDMT', 'SupervennFromDMT'), 16),
#  (('ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',
#    'ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',
#    'MeanScoredT[Drug]'),
#   16),
#  (('SigComLINCSGeneSetSearch', 'EnrichrGenesetSearch', 'MetGeneRxnsSet'), 16),
#  (('GeneCountMatrixFromFile',
#    'AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'CDSignatureFromCounts'),
#   16),
#  (('GTExTissueExpressionFromGene',
#    'BarplotFrom[[TumorGeneExpression]]',
#    'GTExTissueExpressionFromGene'),
#   15),
#  (('UpGeneSetFromSignature',
#    'EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]'),
#   15),
#  (('Limma-Voom', 'UpGeneSetFromSignature', 'EnrichrGenesetSearch'), 15),
#  (('FileInput', 'AnnDataFromFile', 'PCAGraphWithMetadata'), 15),
#  (('GMTConcatenate', 'GMTConsensus', 'EnrichrGenesetSearch'), 14),
#  (('GetRegulatoryElementsForGeneInfoFromGene',
#    'ProteinProductInformationFromGene',
#    'MetgeneMetabolites'),
#   14),
#  (('EnrichrTermSearch[Drug]',
#    'ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_down]',
#    'EnrichrSetTToGMT[Drug]'),
#   14),
#  (('GetRegulatoryElementsForGeneInfoFromGene', 'Input[Gene]', 'MetGeneSearch'),
#   14),
#  (('Input[Set[Gene]]', 'GeneSetIDConv', 'GeneSet_CTD_Kegg'), 14),
#  (('Input[Gene]',
#    'ProteinProductInformationFromGene',
#    'KFTumorExpressionFromGene'),
#   14),
#  (('CDSignatureFromCounts', 'Limma-Voom', 'UpGeneSetFromSignature'), 14),
#  (('VariantInfoFromVariantTerm', 'Input[Set[Variant]]', 'Input[Drug]'), 14),
#  (('KFTumorExpressionFromGene',
#    'GTExTissueExpressionFromGene',
#    'GeneInfoFromGeneTerm'),
#   13),
#  (('GTExTissueExpressionFromGene',
#    'TopKScoredT[Scored[Tissue]]',
#    'OneScoredT[Scored[Tissue]]'),
#   13),
#  (('RegElementInfoFromRegElementTerm',
#    'GetVariantListForRegulatoryElementInfo',
#    'Input[Regulatory_Element]'),
#   13),
#  (('Input[Gene]',
#    'GetRegulatoryElementsForGeneInfoFromGene',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   13),
#  (('AnnDataFromFile', 'FileInput', 'AnnDataFromFile'), 13),
#  (('UpGeneSetFromSignature',
#    'EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[ENCODE_TF_ChIP-seq_2015]'),
#   13),
#  (('Input[Variant]',
#    'VarinatInfoFromVariantTerm',
#    'VarinatInfoFromVariantTerm'),
#   12),
#  (('Input[Regulatory_Element]',
#    'RegElementInfoFromRegElementTerm',
#    'GetVariantListForRegulatoryElementInfo'),
#   12),
#  (('KFTumorExpressionFromGene',
#    'GTExTissueExpressionFromGene',
#    'BarplotFrom[Scored[Tissue]]'),
#   12),
#  (('KFTumorExpressionFromGene',
#    'KFTumorExpressionFromGene',
#    'GTExTissueExpressionFromGene'),
#   12),
#  (('Input[Gene]', 'GTExTissueExpressionFromGene', 'Input[Gene]'), 12),
#  (('SigComLINCSSignatureSearch',
#    'ExtractSigComLINCSSignatureSearch[LINCS L1000 Chemical Perturbagens]',
#    'UpGeneSetFromSignature'),
#   12),
#  (('AnnDataFromFile', 'CDSignatureFromCounts', 'DownGeneSetFromSignature'),
#   12),
#  (('CDSignatureFromCounts', 'Limma-Voom', 'VolcanoPlot'), 12),
#  (('Input[Regulatory_Element]',
#    'RegElementInfoFromRegElementTerm',
#    'Input[Variant]'),
#   12),
#  (('Input[Set[Variant]]', 'Input[Drug]', 'EnrichrTermSearch[Drug]'), 12),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'PCAGraphWithMetadata',
#    'VisualizeLibrarySizesFromAnnData'),
#   12),
#  (('ProteinProductInformation',
#    'GetRegulatoryElementsForGeneInfo',
#    'KFTumorExpression'),
#   11),
#  (('LINCSL1000ReverseSearch',
#    'ProteinProductInformationFromGene',
#    'GTExTissueExpressionFromGene'),
#   11),
#  (('ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_down]',
#    'EnrichrSetTToGMT[Drug]',
#    'GMTConsensus'),
#   11),
#  (('Input[Set[Gene]]', 'FileInput', 'GeneCountMatrixFromFile'), 11),
#  (('Input[Set[Gene]]', 'GeneSet_CTD_Kegg', 'CTD_Graph_Nodes'), 11),
#  (('GTExTissueExpressionFromGene',
#    'TopKScoredT[Scored[Tissue]]',
#    'TopKScoredT[Scored[Drug]]'),
#   11),
#  (('LINCSL1000ReverseSearchExtract[Drug, Up]',
#    'GTExTissueExpressionFromGene',
#    'BarplotFrom[Scored[Drug]]'),
#   11),
#  (('EnrichrSetTToGMT[Drug]', 'GMTUnion', 'EnrichrSetTToGMT[Drug]'), 11),
#  (('GeneSet_CTD_Kegg', 'GeneSet_CTD_Kegg', 'GeneSet_CTD_Kegg'), 11),
#  (('GeneSigFromFile', 'UpGeneSetFromSignature', 'UpGeneSetFromSignature'), 11),
#  (('MyVariantInfoFromVariantTerm',
#    'VariantInfoFromVariantTerm',
#    'GetAlleleRegistryExternalRecordsForVariant'),
#   11),
#  (('CDSignatureFromCounts',
#    'DownGeneSetFromSignature',
#    'EnrichrGenesetSearch'),
#   11),
#  (('AnnDataFromFile', 'CDSignatureFromCounts', 'Limma-Voom'), 11),
#  (('EnrichrTermSearch[Pathway]',
#    'ExtractEnrichrTermSearch[KEGG_2021_Human]',
#    'EnrichrSetTToGMT[Pathway]'),
#   11),
#  (('KFTumorExpressionFromGene',
#    'BarplotFrom[[TumorGeneExpression]]',
#    'GTExTissueExpressionFromGene'),
#   11),
#  (('EnrichrGenesetSearch', 'MetGeneRxnsSet', 'MetgeneMetabolitesGeneSet'), 11),
#  (('GeneTermFromVariantTerm',
#    'MyVariantInfoFromVariantTerm',
#    'VariantInfoFromVariantTerm'),
#   11),
#  (('Input[Drug]', 'EnrichrTermSearch[Drug]', 'Input[Set[Drug]]'), 11),
#  (('OneSetT[Set[Drug]]', 'OneSetT[Set[Drug]]', 'TermToSet[Term[Drug]]'), 11),
#  (('GetRegulatoryElementsForGeneInfo',
#    'ProteinProductInformation',
#    'MetgeneMetabolites'),
#   10),
#  (('MetGeneSearch',
#    'LINCSL1000ReverseSearch',
#    'LINCSL1000ReverseSearchExtract[Gene, Down]'),
#   10),
#  (('Input[Gene]',
#    'LINCSL1000ReverseSearch',
#    'LINCSL1000ReverseSearchExtract[Drug, Up]'),
#   10),
#  (('Input[Set[Variant]]', 'Input[Variant]', 'VarinatInfoFromVariantTerm'), 10),
#  (('GTExTissueExpressionFromGene',
#    'BarplotFrom[Scored[Tissue]]',
#    'OneScoredT[Scored[Tissue]]'),
#   10),
#  (('Input[Variant]',
#    'GeneTermFromVariantTerm',
#    'GTExTissueExpressionFromGene'),
#   10),
#  (('GeneTermFromVariantTerm',
#    'GTExTissueExpressionFromGene',
#    'KFTumorExpressionFromGene'),
#   10),
#  (('Input[Gene]', 'MetGeneSearch', 'MetGeneSearch'), 10),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'PCAGraphWithMetadata',
#    'CDSignatureFromCounts'),
#   10),
#  (('TargetRangerScreenTargets[ARCHS4]',
#    'ARCHS4SignatureSearch[Human]',
#    'SetFromScored[Scored[Gene]]'),
#   10),
#  (('Input[Gene]', 'GeneInfoFromGeneTerm', 'GTExTissueExpression'), 9),
#  (('ProteinProductInformationFromGene',
#    'MetgeneMetabolites',
#    'LINCSL1000ReverseSearchExtract[Drug, Up]'),
#   9),
#  (('FileInput', 'Input[Gene]', 'acss2 gene'), 9),
#  (('GTExTissueExpressionFromGene',
#    'OneScoredT[Scored[Tissue]]',
#    'EnrichrTermSearch[Tissue]'),
#   9),
#  (('VariantInfoFromVariantTerm',
#    'Input[Variant]',
#    'VariantInfoFromVariantTerm'),
#   9),
#  (('DownGeneSetFromSignature',
#    'EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]'),
#   9),
#  (('MetadataMatrixFromFile', 'FileInput', 'GeneCountMatrixFromFile'), 9),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'CDSignatureFromCounts',
#    'Limma-Voom'),
#   9),
#  (('RegElementInfoFromRegElementTerm',
#    'Input[Variant]',
#    'VariantInfoFromVariantTerm'),
#   9),
#  (('EnrichrTermSearch[Drug]', 'Input[Set[Drug]]', 'OneSetT[Set[Drug]]'), 9),
#  (('PCAGraphWithMetadata', 'CDSignatureFromCounts', 'Limma-Voom'), 9),
#  (('PCAGraphWithMetadata',
#    'VisualizeLibrarySizesFromAnnData',
#    'CDSignatureFromCounts'),
#   9),
#  (('ARCHS4SignatureSearch[Human]',
#    'SetFromScored[Scored[Gene]]',
#    'GeneshotGeneSetAugmentation[coexpression]'),
#   9),
#  (('MetGeneRxns', 'MetGeneStudies', 'MetgeneMetabolites'), 8),
#  (('MetGeneRxns',
#    'ProteinProductInformationFromGene',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   8),
#  (('FileInput', 'GMTFromFile', 'SupervennFromGMT'), 8),
#  (('EnrichrSetTToGMT[Drug]', 'GMTConsensus', 'EnrichrGenesetSearch'), 8),
#  (('Input[Gene]', 'MetGeneSearch', 'Input[Set[Gene]]'), 8),
#  (('GMTUnion', 'GMTUnion', 'Input[Drug]'), 8),
#  (('Guilty_By_Association_Genes',
#    'Highly_Connected_Genes',
#    'Guilty_By_Association_Genes'),
#   8),
#  (('GetVariantListForRegulatoryElementInfo',
#    'GetAlleleSpecificEvidencesForThisVariant',
#    'GetxQTL_EvidencesDataForVariantInfo'),
#   8),
#  (('GetRegulatoryElementsForGeneInfoFromGene',
#    'GetRegulatoryElementsForGeneInfoFromGene',
#    'Input[Gene]'),
#   8),
#  (('AnnDataFromFile', 'Limma-Voom', 'VolcanoPlot'), 8),
#  (('ExtractSigComLINCSSignatureSearch[LINCS L1000 Chemical Perturbagens]',
#    'MeanScoredT[Drug]',
#    'FilterFDAApprovedDrugs[Scored[Drug]]'),
#   8),
#  (('EnrichrGenesetSearch', 'Input[Pathway]', 'EnrichrTermSearch[Pathway]'), 8),
#  (('Input[Gene]', 'MetGeneSearch', 'MetGeneRxns'), 8),
#  (('MetGeneSearch', 'MetGeneRxns', 'MetGeneSearch'), 8),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[ENCODE_TF_ChIP-seq_2015]',
#    'ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]'),
#   8),
#  (('MetGeneSearch', 'MetGeneSearch', 'MetGeneRxns'), 8),
#  (('Input[Variant]', 'GeneTermFromVariantTerm', 'Input[Set[Variant]]'), 8),
#  (('AnnDataFromFile',
#    'PCAGraphWithMetadata',
#    'VisualizeLibrarySizesFromAnnData'),
#   8),
#  (('MetadataMatrixFromFile',
#    'AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'VisualizeLibrarySizesFromAnnData'),
#   8),
#  (('SetFromScored[Scored[Gene]]',
#    'GeneshotGeneSetAugmentation[coexpression]',
#    'SetFromScored[Scored[Gene]]'),
#   8),
#  (('GMTConsensus',
#    'EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[GTEx_Tissues_V8_2023]'),
#   7),
#  (('Input[Gene]',
#    'GTExTissueExpressionFromGene',
#    'GTExTissueExpressionFromGene'),
#   7),
#  (('Input[Regulatory_Element]',
#    'RegElementInfoFromRegElementTerm',
#    'GetGenesForRegulatoryElementInfo'),
#   7),
#  (('FileInput', 'GeneCountMatrixFromFile', 'LogNormalizeGeneCountMatrix'), 7),
#  (('ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',
#    'MeanScoredT[Drug]',
#    'FilterFDAApprovedDrugs[Scored[Drug]]'),
#   7),
#  (('FileInput', 'FileInput', 'MetadataMatrixFromFile'), 7),
#  (('VariantInfoFromVariantTerm',
#    'GetAlleleRegistryExternalRecordsForVariant',
#    'GetAlleleSpecificEvidencesForThisVariant'),
#   7),
#  (('OneSetT[Set[Drug]]', 'TermToSet[Term[Drug]]', 'Input[Set[Variant]]'), 7),
#  (('FileInput',
#    'GeneCountMatrixFromFile',
#    'AnnDataFromGeneCountMatrixAndMetadataMatrix'),
#   7),
#  (('FileInput', 'GeneCountMatrixFromFile', 'Transpose'), 7),
#  (('PCAGraphWithMetadata',
#    'VisualizeLibrarySizesFromAnnData',
#    'LabelAnnDataMetadata'),
#   7),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'VisualizeLibrarySizesFromAnnData',
#    'LabelAnnDataMetadata'),
#   7),
#  (('VisualizeLibrarySizesFromAnnData', 'CDSignatureFromCounts', 'Limma-Voom'),
#   7),
#  (('Input[Set[Regulatory_Element]]',
#    'Input[Variant]',
#    'GeneTermFromVariantTerm'),
#   7),
#  (('GeneshotGeneSetAugmentation[coexpression]',
#    'SetFromScored[Scored[Gene]]',
#    'GenesetsToGMT'),
#   7),
#  (('FileInput', 'MetadataMatrixFromFile', 'CDSignatureFromCounts'), 6),
#  (('GetRegulatoryElementsForGeneInfo',
#    'KFTumorExpression',
#    'ExtractEnrichrGeneSearch[LINCS_L1000_CRISPR_KO_Consensus_Sigs]'),
#   6),
#  (('LINCSL1000ReverseSearchExtract[Gene, Down]',
#    'IDGFilter[Scored[Gene], all]',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   6),
#  (('GTExTissueExpressionFromGene',
#    'GeneInfoFromGeneTerm',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   6),
#  (('GTExTissueExpressionFromGene',
#    'OneScoredT[Scored[Tissue]]',
#    'KFTumorExpressionFromGene'),
#   6),
#  (('ProteinProductInformationFromGene',
#    'GTExTissueExpressionFromGene',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   6),
#  (('LINCSL1000ReverseSearch',
#    'LINCSL1000ReverseSearchExtract[Gene, Down]',
#    'BarplotFrom[Scored[Gene]]'),
#   6),
#  (('Input[Gene]', 'Input[Regulatory_Element]', 'Input[Set[Variant]]'), 6),
#  (('TopKScoredT[Scored[Tissue]]',
#    'OneScoredT[Scored[Tissue]]',
#    'OneScoredT[Scored[Tissue]]'),
#   6),
#  (('GetVariantListForRegulatoryElementInfo',
#    'Input[Regulatory_Element]',
#    'RegElementInfoFromRegElementTerm'),
#   6),
#  (('GeneSet_CTD_Kegg', 'CTD_Graph_Nodes', 'CTD_Graph_Nodes'), 6),
#  (('KFTumorExpressionFromGene',
#    'GTExTissueExpressionFromGene',
#    'TopKScoredT[Scored[Tissue]]'),
#   6),
#  (('ProteinProductInformationFromGene',
#    'KFTumorExpressionFromGene',
#    'MetGeneSearch'),
#   6),
#  (('Input[Set[Gene]]', 'GeneSetIDConv', 'c1'), 6),
#  (('GTExTissueExpressionFromGene',
#    'BarplotFrom[Scored[Drug]]',
#    'BarplotFrom[Scored[Drug]]'),
#   6),
#  (('EnrichrSetTToGMT[Phenotype]',
#    'EnrichrSetTToGMT[Phenotype]',
#    'GMTConsensus'),
#   6),
#  (('GMTUnion', 'EnrichrSetTToGMT[Drug]', 'GMTConsensus'), 6),
#  (('GeneSet_CTD_Kegg', 'GeneSet_CTD_Kegg', 'GeneSet_CTD_String'), 6),
#  (('VariantInfoFromVariantTerm',
#    'VariantInfoFromVariantTerm',
#    'GetRegulatoryElementForThisVariant'),
#   6),
#  (('VariantInfoFromVariantTerm',
#    'GetRegulatoryElementForThisVariant',
#    'GetAlleleRegistryExternalRecordsForVariant'),
#   6),
#  (('GeneCountMatrixFromFile', 'FileInput', 'AnnDataFromFile'), 6),
#  (('UpGeneSetFromSignature',
#    'UpGeneSetFromSignature',
#    'DownGeneSetFromSignature'),
#   6),
#  (('Input[Variant]',
#    'MyVariantInfoFromVariantTerm',
#    'VariantInfoFromVariantTerm'),
#   6),
#  (('EnrichrGenesetSearch',
#    'ScoredGenesFromSignature',
#    'SigComLINCSSignatureSearch'),
#   6),
#  (('MetGeneRxnsSet', 'MetgeneMetabolitesGeneSet', 'MetGeneStudiesGeneSet'), 6),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]',
#    'BarplotFrom[Scored[Gene]]'),
#   6),
#  (('ExtractEnrichrGenesetSearch[ENCODE_TF_ChIP-seq_2015]',
#    'ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]',
#    'ExtractEnrichrGenesetSearch[ChEA_2022]'),
#   6),
#  (('GeneTermFromVariantTerm', 'Input[Set[Variant]]', 'Input[Variant]'), 6),
#  (('GeneCountMatrixFromFile',
#    'AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'Limma-Voom'),
#   6),
#  (('GeneCountMatrixFromFile', 'Transpose', 'AnnDataFromFile'), 6),
#  (('FileInput', 'Input[Phenotype]', 'Input[Tissue]'), 6),
#  (('Input[Gene]', 'MetGeneSearch', 'MetGeneStudies'), 6),
#  (('Input[Set[Gene]]', 'GeneSetIDConv', 'ExtractProteinIDs'), 5),
#  (('MetgeneMetabolites',
#    'LINCSL1000ReverseSearchExtract[Drug, Up]',
#    'LINCSL1000ReverseSearchExtract[Gene, Up]'),
#   5),
#  (('GMTConsensus',
#    'EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[ARCHS4_Tissues]'),
#   5),
#  (('Input[Set[Variant]]',
#    'Input[Regulatory_Element]',
#    'RegElementInfoFromRegElementTerm'),
#   5),
#  (('Input[Gene]',
#    'ProteinProductInformationFromGene',
#    'LINCSL1000ReverseSearch'),
#   5),
#  (('RegElementInfoFromRegElementTerm',
#    'GetVariantListForRegulatoryElementInfo',
#    'GetGenesForRegulatoryElementInfo'),
#   5),
#  (('BarplotFrom[Scored[Tissue]]',
#    'OneScoredT[Scored[Tissue]]',
#    'EnrichrTermSearch[Tissue]'),
#   5),
#  (('Input[Gene]', 'KFTumorExpressionFromGene', 'BRCA'), 5),
#  (('EnrichrTermSearch[Pathway]',
#    'ExtractEnrichrTermSearch[Human_Phenotype_Ontology]',
#    'EnrichrSetTToGMT[Phenotype]'),
#   5),
#  (('MetGeneRxns', 'MetGeneSearch', 'MetGeneRxns'), 5),
#  (('Input[Gene]',
#    'GetRegulatoryElementsForGeneInfoFromGene',
#    'Input[Set[Variant]]'),
#   5),
#  (('ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]',
#    'ExtractEnrichrGenesetSearch[ChEA_2022]',
#    'DownGeneSetFromSignature'),
#   5),
#  (('Limma-Voom', 'UpGeneSetFromSignature', 'VolcanoPlot'), 5),
#  (('RegElementInfoFromRegElementTerm',
#    'GetGenesForRegulatoryElementInfo',
#    'IDGFilter[Set[Gene], darkionchannel]'),
#   5),
#  (('GetAlleleRegistryExternalRecordsForVariant',
#    'GetAlleleSpecificEvidencesForThisVariant',
#    'GetxQTL_EvidencesDataForVariantInfo'),
#   5),
#  (('OneSetT[Set[Drug]]', 'OneSetT[Set[Drug]]', 'OneSetT[Set[Drug]]'), 5),
#  (('TermToSet[Term[Drug]]', 'Input[Set[Variant]]', 'Input[Gene]'), 5),
#  (('Input[Gene]',
#    'GetRegulatoryElementsForGeneInfoFromGene',
#    'Input[Regulatory_Element]'),
#   5),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'Limma-Voom',
#    'UpGeneSetFromSignature'),
#   5),
#  (('Transpose', 'AnnDataFromFile', 'VisualizeLibrarySizes'), 5),
#  (('VisualizeLibrarySizesFromAnnData', 'LabelAnnDataMetadata', 'Limma-Voom'),
#   5),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]',
#    'BarChartFrom[Scored[Gene]]'),
#   5),
#  (('AnnDataFromFile', 'PCAGraphWithMetadata', 'CDSignatureFromCounts'), 5),
#  (('GeneTermFromVariantTerm',
#    'KFTumorExpressionFromGene',
#    'VariantInfoFromVariantTerm'),
#   5),
#  (('TargetRangerScreenTargets[ARCHS4]',
#    'ARCHS4SignatureSearch[Human]',
#    'TopKScoredT[Scored[Gene]]'),
#   5),
#  (('MetGeneSearch', 'MetGeneStudies', 'MetGeneSearch'), 5),
#  (('Input[Gene]', 'LINCSL1000ReverseSearch', 'MetGeneSearch'), 4),
#  (('Input[Gene]', 'GTExTissueExpressionFromGene', 'KFTumorExpressionFromGene'),
#   4),
#  (('OneScoredT[Scored[Tissue]]',
#    'EnrichrTermSearch[Tissue]',
#    'Input[Disease]'),
#   4),
#  (('TopKScoredT[Scored[Tissue]]',
#    'TopKScoredT[Scored[Drug]]',
#    'TopKScoredT[Scored[Drug]]'),
#   4),
#  (('Input[Variant]', 'VariantInfoFromVariantTerm', 'Input[Set[Variant]]'), 4),
#  (('KFTumorExpressionFromGene',
#    'GTExTissueExpressionFromGene',
#    'GTExTissueExpressionFromGene'),
#   4),
#  (('GTExTissueExpressionFromGene',
#    'Input[Gene]',
#    'GTExTissueExpressionFromGene'),
#   4),
#  (('ExtractSigComLINCSSignatureSearch[LINCS L1000 Chemical Perturbagens]',
#    'UpGeneSetFromSignature',
#    'EnrichrGenesetSearch'),
#   4),
#  (('Input[Gene]', 'MetGeneSearch', 'MetgeneMetabolites'), 4),
#  (('Input[Gene]',
#    'GetRegulatoryElementsForGeneInfoFromGene',
#    'Input[Variant]'),
#   4),
#  (('KFTumorExpressionFromGene',
#    'BarplotFrom[[TumorGeneExpression]]',
#    'GeneTermFromVariantTerm'),
#   4),
#  (('AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'CDSignatureFromCounts',
#    'DownGeneSetFromSignature'),
#   4),
#  (('AnnDataFromFile', 'CDSignatureFromCounts', 'UpGeneSetFromSignature'), 4),
#  (('ExtractEnrichrGenesetSearch[ChEA_2022]',
#    'DownGeneSetFromSignature',
#    'EnrichrGenesetSearch'),
#   4),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[ENCODE_TF_ChIP-seq_2015]',
#    'Limma-Voom'),
#   4),
#  (('GetGenesForRegulatoryElementInfo',
#    'IDGFilter[Set[Gene], darkionchannel]',
#    'IDGFilter[Set[Gene], ionchannel]'),
#   4),
#  (('RegElementInfoFromRegElementTerm',
#    'GetGenesForRegulatoryElementInfo',
#    'Input[Set[Regulatory_Element]]'),
#   4),
#  (('MetGeneSearch', 'MetGeneRxns', 'MetGeneStudies'), 4),
#  (('FileInput', 'AnnDataFromFile', 'LabelAnnDataMetadata'), 4),
#  (('LabelAnnDataMetadata', 'Limma-Voom', 'UpGeneSetFromSignature'), 4),
#  (('VisualizeLibrarySizesFromAnnData',
#    'LabelAnnDataMetadata',
#    'AnnDataFromFile'),
#   4),
#  (('PCAGraphWithMetadata',
#    'CDSignatureFromCounts',
#    'DownGeneSetFromSignature'),
#   4),
#  (('KFTumorExpressionFromGene',
#    'VariantInfoFromVariantTerm',
#    'GetAlleleSpecificEvidencesForThisVariant'),
#   4),
#  (('MetGeneStudies', 'MetGeneSearch', 'MetgeneMetabolites'), 4),
#  (('FileInput', 'GeneCountMatrixFromFile', 'PCABokehPlotFromGeneCountMatrix'),
#   3),
#  (('BarplotFrom[[TumorGeneExpression]]',
#    'GeneTermFromVariantTerm',
#    'GTExTissueExpressionFromGene'),
#   3),
#  (('MetadataMatrixFromFile', 'FileInput', 'FileInput'), 3),
#  (('GetRegulatoryElementsForGeneInfoFromGene',
#    'Input[Set[Variant]]',
#    'Input[Variant]'),
#   3),
#  (('CDSignatureFromCounts',
#    'DownGeneSetFromSignature',
#    'UpGeneSetFromSignature'),
#   3),
#  (('ExtractEnrichrGenesetSearch[ENCODE_TF_ChIP-seq_2015]',
#    'Limma-Voom',
#    'UpGeneSetFromSignature'),
#   3),
#  (('IDGFilter[Set[Gene], darkionchannel]',
#    'IDGFilter[Set[Gene], ionchannel]',
#    'GetGenesForRegulatoryElementInfo'),
#   3),
#  (('GetAlleleSpecificEvidencesForThisVariant',
#    'GetxQTL_EvidencesDataForVariantInfo',
#    'GeneTermFromVariantTerm'),
#   3),
#  (('Input[Variant]', 'VariantInfoFromVariantTerm', 'GeneTermFromVariantTerm'),
#   3),
#  (('GeneTermFromVariantTerm',
#    'MyVariantInfoFromVariantTerm',
#    'Input[Variant]'),
#   3),
#  (('Input[Set[Variant]]', 'Input[Gene]', 'Input[Set[Gene]]'), 3),
#  (('GetRegulatoryElementsForGeneInfoFromGene',
#    'Input[Regulatory_Element]',
#    'RegElementInfoFromRegElementTerm'),
#   3),
#  (('UpGeneSetFromSignature', 'EnrichrGenesetSearch', 'CDSignatureFromCounts'),
#   3),
#  (('AnnDataFromFile', 'VisualizeLibrarySizes', 'PCAGraphWithoutMetadata'), 3),
#  (('FileInput', 'AnnDataFromFile', 'VisualizeLibrarySizesFromAnnData'), 3),
#  (('Input[Phenotype]', 'Input[Tissue]', 'EnrichrTermSearch[Tissue]'), 3),
#  (('UpGeneSetFromSignature', 'VolcanoPlot', 'EnrichrGenesetSearch'), 3),
#  (('VariantInfoFromVariantTerm',
#    'GetAlleleSpecificEvidencesForThisVariant',
#    'GetAlleleRegistryExternalRecordsForVariant'),
#   3),
#  (('Input[Set[Gene]]', 'GeneSetIDConv', 'EnrichrGenesetSearch'), 3),
#  (('GetRegulatoryElementForThisVariant',
#    'GetAlleleRegistryExternalRecordsForVariant',
#    'GetAlleleSpecificEvidencesForThisVariant'),
#   3),
#  (('ARCHS4SignatureSearch[Human]',
#    'TopKScoredT[Scored[Gene]]',
#    'SetFromScored[Scored[Gene]]'),
#   3),
#  (('MetGeneSearch', 'MetgeneMetabolites', 'MGMetTable2MetSet'), 3),
#  (('MetadataMatrixFromFile', 'CDSignatureFromCounts', 'GMTFromSignature'), 2),
#  (('GeneInfoFromGeneTerm',
#    'GTExTissueExpression',
#    'BarplotFrom[Scored[Tissue]]'),
#   2),
#  (('Input[Variant]',
#    'VarinatInfoFromVariantTerm',
#    'GetRegulatoryElementsForVariantInfo'),
#   2),
#  (('Input[Gene]', 'GeneInfoFromGeneTerm', 'ProteinProductInformation'), 2),
#  (('GeneSetIDConv', 'ExtractProteinIDs', 'GlycosylationsFromProteins'), 2),
#  (('KFTumorExpression',
#    'ExtractEnrichrGeneSearch[LINCS_L1000_CRISPR_KO_Consensus_Sigs]',
#    'ExtractEnrichrGeneSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]'),
#   2),
#  (('GetRegulatoryElementsForGeneInfo',
#    'ProteinProductInformation',
#    'MetGeneRxns'),
#   2),
#  (('ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'EnrichrSetTToGMT[Drug]',
#    'GMTConcatenate'),
#   2),
#  (('LINCSL1000ReverseSearchExtract[Gene, Up]',
#    'LINCSL1000ReverseSearchExtract[Drug, Down]',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   2),
#  (('LINCSL1000ReverseSearch', 'MetGeneSearch', 'KFTumorExpressionFromGene'),
#   2),
#  (('LINCSL1000ReverseSearchExtract[Drug, Down]',
#    'MetGeneSearch',
#    'MetGeneRxns'),
#   2),
#  (('LINCSL1000ReverseSearchExtract[Drug, Up]',
#    'LINCSL1000ReverseSearchExtract[Gene, Up]',
#    'MetGeneRxns'),
#   2),
#  (('ProteinProductInformationFromGene',
#    'GetRegulatoryElementsForGeneInfoFromGene',
#    'IDGFilter[Scored[Gene], all]'),
#   2),
#  (('IDGFilter[Scored[Gene], all]',
#    'GetRegulatoryElementsForGeneInfoFromGene',
#    'ProteinProductInformationFromGene'),
#   2),
#  (('GeneInfoFromGeneTerm',
#    'GetRegulatoryElementsForGeneInfoFromGene',
#    'GTExTissueExpressionFromGene'),
#   2),
#  (('OneScoredT[Scored[Tissue]]',
#    'KFTumorExpressionFromGene',
#    'Input[Set[Regulatory_Element]]'),
#   2),
#  (('Input[Gene]',
#    'EnrichrGeneSearch',
#    'ExtractEnrichrGeneSearch[ARCHS4_TFs_Coexp]'),
#   2),
#  (('GTExTissueExpressionFromGene',
#    'GetRegulatoryElementsForGeneInfoFromGene',
#    'KFTumorExpressionFromGene'),
#   2),
#  (('LINCSL1000ReverseSearchExtract[Gene, Down]',
#    'BarplotFrom[Scored[Gene]]',
#    'MetGeneStudies'),
#   2),
#  (('Input[Gene]',
#    'KFTumorExpressionFromGene',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   2),
#  (('Input[Gene]', 'GeneIDConv', 'ProteinProductInformationFromGene'), 2),
#  (('Input[Metabolite]', 'MetaboliteInfo', 'Input[Set[Variant]]'), 2),
#  (('Input[Metabolite]', 'MetaboliteInfo', 'Input[Variant]'), 2),
#  (('Input[Drug]',
#    'EnrichrTermSearch[Drug]',
#    'ExtractEnrichrTermSearch[ChEA_2022]'),
#   2),
#  (('ExtractEnrichrTermSearch[LINCS_L1000_Chem_Pert_Consensus_Sigs]',
#    'EnrichrSetTToGMT[Drug]',
#    'GMTIntersection'),
#   2),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[ARCHS4_Tissues]',
#    'BarplotFrom[Scored[Tissue]]'),
#   2),
#  (('VarinatInfoFromVariantTerm',
#    'VarinatInfoFromVariantTerm',
#    'GetRegulatoryElementsForVariantInfo'),
#   2),
#  (('VarinatInfoFromVariantTerm', 'VarinatInfoFromVariantTerm', 'FileInput'),
#   2),
#  (('FileInput', 'Input[Gene]', 'LINCSL1000ReverseSearch'), 2),
#  (('Input[Gene]', 'acss2 gene', 'Input[Set[Gene]]'), 2),
#  (('Input[Gene]', 'acss2 gene', 'FileInput'), 2),
#  (('Input[Gene]',
#    'GetRegulatoryElementsForGeneInfoFromGene',
#    'EnrichrGeneSearch'),
#   2),
#  (('Input[Regulatory_Element]', 'Input[Set[Variant]]', 'Input[Gene]'), 2),
#  (('OneScoredT[Scored[Tissue]]',
#    'OneScoredT[Scored[Tissue]]',
#    'EnrichrTermSearch[Tissue]'),
#   2),
#  (('GTExTissueExpressionFromGene',
#    'OneScoredT[Scored[Tissue]]',
#    'BarplotFrom[Scored[Tissue]]'),
#   2),
#  (('ProteinProductInformationFromGene',
#    'LINCSL1000ReverseSearch',
#    'LINCSL1000ReverseSearchExtract[Drug, Down]'),
#   2),
#  (('MetGeneSearch', 'Input[Set[Gene]]', 'GeneSet_CTD_Kegg'), 2),
#  (('GeneCountMatrixFromFile',
#    'MetadataMatrixFromFile',
#    'CDSignatureFromCounts'),
#   2),
#  (('Input[Set[Gene]]', 'GeneSetIDConv', 'MetGeneRxnsSet'), 2),
#  (('Input[Set[Gene]]', 'GeneSetIDConv', 'IDGFilter[Set[Gene], gpcr]'), 2),
#  (('GeneSetIDConv', 'GeneSet_CTD_Kegg', 'GeneSetIDConv'), 2),
#  (('CTD_Graph_Nodes', 'CTD_Graph_Nodes', 'Guilty_By_Association_Genes'), 2),
#  (('GeneSetIDConv', 'GeneSet_CTD_Kegg', 'GeneSet_CTD_String'), 2),
#  (('GTExTissueExpressionFromGene',
#    'TopKScoredT[Scored[Tissue]]',
#    'BarplotFrom[Scored[Tissue]]'),
#   2),
#  (('KFTumorExpressionFromGene', 'MetGeneSearch', 'LINCSL1000ReverseSearch'),
#   2),
#  (('GeneCountMatrixFromFile',
#    'LogNormalizeGeneCountMatrix',
#    'PCABokehPlotFromGeneCountMatrix'),
#   2),
#  (('LINCSL1000ReverseSearch',
#    'LINCSL1000ReverseSearchExtract[Drug, Up]',
#    'SetFromScored[Scored[Drug]]'),
#   2),
#  (('Input[Gene]', 'GeneInfoFromGeneTerm', 'MetGeneSearch'), 2),
#  (('GeneSetIDConv', 'c1', 'EnrichrSetTToSetT[Pathway]'), 2),
#  (('BarplotFrom[Scored[Drug]]',
#    'BarplotFrom[Scored[Drug]]',
#    'BarplotFrom[Scored[Tissue]]'),
#   2),
#  (('Input[Set[Gene]]', 'GeneSet_CTD_String', 'GeneSet_CTD_String'), 2),
#  (('EnrichrSetTToGMT[Phenotype]',
#    'EnrichrSetTToGMT[Phenotype]',
#    'GMTConcatenate'),
#   2),
#  (('EnrichrSetTToGMT[Phenotype]', 'GMTConsensus', 'GMTConsensus'), 2),
#  (('GMTUnion', 'Input[Drug]', 'Input[Drug]'), 2),
#  (('EnrichrSetTToGMT[Drug]', 'GMTConsensus', 'EnrichrTermSearch[Drug]'), 2),
#  (('Input[Set[Gene]]', 'Input[Gene]', 'LINCSL1000ReverseSearch'), 2),
#  (('GeneSet_CTD_Kegg', 'GeneSet_CTD_String', 'GeneSet_CTD_String'), 2),
#  (('GetRegulatoryElementsForGeneInfoFromGene',
#    'Input[Gene]',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   2),
#  (('KFTumorExpressionFromGene',
#    'KFTumorExpressionFromGene',
#    'GeneInfoFromGeneTerm'),
#   2),
#  (('AnnDataFromFile', 'CDSignatureFromCounts', 'CDSignatureFromCounts'), 2),
#  (('UpGeneSetFromSignature',
#    'DownGeneSetFromSignature',
#    'DownGeneSetFromSignature'),
#   2),
#  (('Input[Gene]', 'GTExTissueExpressionFromGene', 'MetGeneSearch'), 2),
#  (('GetVariantListForRegulatoryElementInfo',
#    'GetGenesForRegulatoryElementInfo',
#    'GeneSet_CTD_Kegg'),
#   2),
#  (('Input[Gene]',
#    'GTExTissueExpressionFromGene',
#    'TopKScoredT[Scored[Tissue]]'),
#   2),
#  (('OneScoredT[Scored[Tissue]]',
#    'EnrichrTermSearch[Tissue]',
#    'ExtractEnrichrTermSearch[GO_Biological_Process_2021]'),
#   2),
#  (('GTExTissueExpressionFromGene',
#    'BarplotFrom[Scored[Tissue]]',
#    'MetGeneSearch'),
#   2),
#  (('KFTumorExpressionFromGene',
#    'BRCA',
#    'ExtractEnrichrGenesetSearch[WikiPathways_2019_Human]'),
#   2),
#  (('LINCSL1000ReverseSearch',
#    'LINCSL1000ReverseSearchExtract[Drug, Up]',
#    'LINCSL1000ReverseSearchExtract[Drug, Down]'),
#   2),
#  (('Input[Disease]',
#    'EnrichrTermSearch[Disease]',
#    'ExtractEnrichrTermSearch[GTEx_Tissues_V8_2023]'),
#   2),
#  (('GeneSigFromFile',
#    'ScoredGenesFromSignature',
#    'SigComLINCSSignatureSearch'),
#   2),
#  (('AnnDataFromFile', 'CDSignatureFromCounts', 'VolcanoPlot'), 2),
#  (('FileInput', 'GeneCountMatrixFromFile', 'VisualizeLibrarySizes'), 2),
#  (('Limma-Voom', 'VolcanoPlot', 'VolcanoPlot'), 2),
#  (('ExtractSigComLINCSSignatureSearch[LINCS L1000 Chemical Perturbagens]',
#    'MeanScoredT[Drug]',
#    'UpGeneSetFromSignature'),
#   2),
#  (('SigComLINCSGeneSetSearch',
#    'ExtractSigComLINCSGeneSetSearch[LINCS L1000 Chemical Perturbagens]',
#    'ExtractEnrichrTermSearch[KEGG_2019_Human]'),
#   2),
#  (('Input[Set[Gene]]', 'Input[Drug]', 'EnrichrGenesetSearch'), 2),
#  (('Input[Pathway]', 'EnrichrTermSearch[Pathway]', 'EnrichrGenesetSearch'), 2),
#  (('GetRegulatoryElementsForGeneInfoFromGene',
#    'Input[Variant]',
#    'GeneTermFromVariantTerm'),
#   2),
#  (('Input[Set[Variant]]', 'Input[Variant]', 'Input[Regulatory_Element]'), 2),
#  (('KFTumorExpressionFromGene',
#    'BarplotFrom[[TumorGeneExpression]]',
#    'ExtractEnrichrGenesetSearch[GTEx_Tissues_V8_2023]'),
#   2),
#  (('ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]',
#    'BarplotFrom[Scored[Gene]]',
#    'ExtractEnrichrGenesetSearch[GO_Biological_Process_2021]'),
#   2),
#  (('DownGeneSetFromSignature',
#    'UpGeneSetFromSignature',
#    'EnrichrGenesetSearch'),
#   2),
#  (('EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]',
#    'ExtractEnrichrGenesetSearch[ChEA_2022]'),
#   2),
#  (('AnnDataFromFile', 'Limma-Voom', 'UpGeneSetFromSignature'), 2),
#  (('IDGFilter[Set[Gene], ionchannel]',
#    'GetGenesForRegulatoryElementInfo',
#    'Input[Set[Variant]]'),
#   2),
#  (('GetGenesForRegulatoryElementInfo',
#    'Input[Set[Regulatory_Element]]',
#    'RegElementInfoFromRegElementTerm'),
#   2),
#  (('MetGeneSearch', 'MetGeneRxns', 'MetgeneMetabolites'), 2),
#  (('VariantInfoFromVariantTerm',
#    'GeneTermFromVariantTerm',
#    'MyVariantInfoFromVariantTerm'),
#   2),
#  (('Input[Regulatory_Element]',
#    'RegElementInfoFromRegElementTerm',
#    'Input[Set[Regulatory_Element]]'),
#   2),
#  (('MetGeneRxns', 'MetGeneStudies', 'MetGeneSearch'), 2),
#  (('Input[Gene]', 'Input[Gene]', 'GTExTissueExpressionFromGene'), 2),
#  (('EnrichrGenesetSearch', 'CDSignatureFromCounts', 'UpGeneSetFromSignature'),
#   2),
#  (('VisualizeLibrarySizes', 'PCAGraphWithoutMetadata', 'PCAGraphWithMetadata'),
#   2),
#  (('AnnDataFromFile',
#    'VisualizeLibrarySizesFromAnnData',
#    'PCAGraphWithMetadata'),
#   2),
#  (('ProteinProductInformationFromGene',
#    'KFTumorExpressionFromGene',
#    'GeneIDConv'),
#   2),
#  (('VolcanoPlot',
#    'EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]'),
#   2),
#  (('GetAlleleSpecificEvidencesForThisVariant',
#    'GetAlleleRegistryExternalRecordsForVariant',
#    'GetRegulatoryElementForThisVariant'),
#   2),
#  (('GeneSetIDConv', 'EnrichrGenesetSearch', 'OneSetT[Set[Gene]]'), 2),
#  (('GetAlleleRegistryExternalRecordsForVariant',
#    'GetAlleleSpecificEvidencesForThisVariant',
#    'RegElementInfoFromRegElementTerm'),
#   2),
#  (('TopKScoredT[Scored[Gene]]',
#    'SetFromScored[Scored[Gene]]',
#    'SigComLINCSGeneSetSearch'),
#   2),
#  (('SetFromScored[Scored[Gene]]', 'GenesetsToGMT', 'GMTUnion'), 2),
#  (('SetFromScored[Scored[Gene]]', 'GenesetsToGMT', 'SupervennFromGMT'), 2),
#  (('MetgeneMetabolites', 'MGMetTable2MetSet', 'MetaboliteSetInfo'), 2),
#  (('Input[Variant]',
#    'GeneTermFromVariantTerm',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   1),
#  (('GeneCountMatrixFromFile', 'PCAGraph', 'AnnDataFromFile'), 1),
#  (('MetadataMatrixFromFile', 'FileInput', 'GMTFromFile'), 1),
#  (('MetadataMatrixFromFile', 'FileInput', 'AnnDataFromFile'), 1),
#  (('FileInput', 'FileInput', 'AnnDataFromFile'), 1),
#  (('Input[Set[Variant]]', 'Input[Variant]', 'MyVariantInfoFromVariantTerm'),
#   1),
#  (('Input[Set[Variant]]', 'Input[Variant]', 'GeneTermFromVariantTerm'), 1),
#  (('Input[Variant]',
#    'Input[Regulatory_Element]',
#    'RegElementInfoFromRegElementTerm'),
#   1),
#  (('BarplotFrom[[TumorGeneExpression]]',
#    'ExtractEnrichrGenesetSearch[GTEx_Tissues_V8_2023]',
#    'BarplotFrom[Scored[Tissue]]'),
#   1),
#  (('FileInput', 'MetadataMatrixFromFile', 'GeneCountMatrixFromFile'), 1),
#  (('BarplotFrom[Scored[Gene]]',
#    'ExtractEnrichrGenesetSearch[GO_Biological_Process_2021]',
#    'BarplotFrom[Scored[Pathway]]'),
#   1),
#  (('UpGeneSetFromSignature',
#    'EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[ChEA_2022]'),
#   1),
#  (('ExtractEnrichrGenesetSearch[ENCODE_TF_ChIP-seq_2015]',
#    'ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]',
#    'ExtractEnrichrGenesetSearch[ARCHS4_Tissues]'),
#   1),
#  (('ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]',
#    'ExtractEnrichrGenesetSearch[ChEA_2022]',
#    'ExtractEnrichrGenesetSearch[ENCODE_TF_ChIP-seq_2015]'),
#   1),
#  (('UpGeneSetFromSignature',
#    'EnrichrGenesetSearch',
#    'ExtractEnrichrGenesetSearch[GO_Biological_Process_2021]'),
#   1),
#  (('MetadataMatrixFromFile',
#    'AnnDataFromGeneCountMatrixAndMetadataMatrix',
#    'PCAGraph'),
#   1),
#  (('RegElementInfoFromRegElementTerm',
#    'Input[Variant]',
#    'GeneTermFromVariantTerm'),
#   1),
#  (('Input[Variant]', 'Input[Set[Variant]]', 'MyVariantInfoFromVariantTerm'),
#   1),
#  (('Input[Set[Regulatory_Element]]',
#    'RegElementInfoFromRegElementTerm',
#    'GetVariantListForRegulatoryElementInfo'),
#   1),
#  (('AnnDataFromFile', 'FileInput', 'CDSignatureFromCounts'), 1),
#  (('MetGeneRxns', 'MetgeneMetabolites', 'MetGeneStudies'), 1),
#  (('GetxQTL_EvidencesDataForVariantInfo',
#    'GeneTermFromVariantTerm',
#    'GeneTermFromVariantTerm'),
#   1),
#  (('GeneTermFromVariantTerm',
#    'MyVariantInfoFromVariantTerm',
#    'MyVariantInfoFromVariantTerm'),
#   1),
#  (('MyVariantInfoFromVariantTerm',
#    'Input[Variant]',
#    'VariantInfoFromVariantTerm'),
#   1),
#  (('OneSetT[Set[Drug]]',
#    'TermToSet[Term[Drug]]',
#    'FilterFDAApprovedDrugs[Set[Drug]]'),
#   1),
#  (('Input[Gene]', 'Input[Set[Gene]]', 'OneSetT[Set[Gene]]'), 1),
#  (('MetGeneSearch', 'MetgeneMetabolites', 'MetGeneStudies'), 1),
#  (('MetGeneStudies', 'MetGeneSearch', 'MetGeneRxns'), 1),
#  (('Input[Gene]',
#    'EnrichrTermSearch[Gene]',
#    'ExtractEnrichrTermSearch[ARCHS4_Tissues]'),
#   1),
#  (('Input[Set[Metabolite]]', 'MetaboliteSetInfo', 'MetaboliteSetInfo'), 1),
#  (('AnnDataFromFile', 'LabelAnnDataMetadata', 'LabelAnnDataMetadata'), 1),
#  (('AnnDataFromFile',
#    'VisualizeLibrarySizes',
#    'PCABokehPlotFromGeneCountMatrix'),
#   1),
#  (('PCAGraphWithoutMetadata',
#    'PCAGraphWithMetadata',
#    'VisualizeLibrarySizesFromAnnData'),
#   1),
#  (('VisualizeLibrarySizesFromAnnData',
#    'PCAGraphWithMetadata',
#    'LabelAnnDataMetadata'),
#   1),
#  (('Input[Gene]', 'EnrichrGeneSearch', 'Input[Metabolite]'), 1),
#  (('Input[Tissue]', 'EnrichrTermSearch[Tissue]', 'EnrichrTermSearch[Tissue]'),
#   1),
#  (('LabelAnnDataMetadata', 'AnnDataFromFile', 'CDSignatureFromCounts'), 1),
#  (('KFTumorExpressionFromGene',
#    'GeneIDConv',
#    'GetRegulatoryElementsForGeneInfoFromGene'),
#   1),
#  (('Input[Gene]',
#    'LINCSL1000ReverseSearch',
#    'ProteinProductInformationFromGene'),
#   1),
#  (('ExtractEnrichrGenesetSearch[ARCHS4_TFs_Coexp]',
#    'BarChartFrom[Scored[Gene]]',
#    'VisualizeLibrarySizesFromAnnData'),
#   1),
#  (('PCAGraphWithMetadata', 'VisualizeLibrarySizesFromAnnData', 'Limma-Voom'),
#   1),
#  (('AnnDataFromFile', 'FileInput', 'GeneCountMatrixFromFile'), 1),
#  (('Input[Gene]', 'Input[Drug]', 'LINCSL1000ReverseSearch'), 1),
#  (('GetAlleleRegistryExternalRecordsForVariant',
#    'GetRegulatoryElementForThisVariant',
#    'RegElementInfoFromRegElementTerm'),
#   1),
#  (('EnrichrGenesetSearch', 'OneSetT[Set[Gene]]', 'MetGeneSearch'), 1),
#  (('GeneTermFromVariantTerm',
#    'MyVariantInfoFromVariantTerm',
#    'GeneTermFromMyVariantInfo'),
#   1),
#  (('GetAlleleSpecificEvidencesForThisVariant',
#    'RegElementInfoFromRegElementTerm',
#    'GetxQTL_EvidencesDataForVariantInfo'),
#   1),
#  (('TargetRangerScreenTargets[ARCHS4]',
#    'ARCHS4SignatureSearch[Human]',
#    'SigComLINCSSignatureSearch'),
#   1),
#  (('SetFromScored[Scored[Gene]]',
#    'SigComLINCSGeneSetSearch',
#    'BarChartFrom[Scored[Gene]]'),
#   1),
#  (('GenesetsToGMT', 'GMTUnion', 'SupervennFromGMT'), 1),
#  (('GenesetsToGMT', 'SupervennFromGMT', 'SigComLINCSGeneSetSearch'), 1),
#  (('MGMetTable2MetSet', 'MetaboliteSetInfo', 'Call_MetENP_on_MetSet'), 1),
#  (('GMTConcatenate', 'SupervennFromGMT', 'Input[Gene]'), 1),
#  (('Input[Gene]', 'MetGeneSearch', 'GTExTissueExpressionFromGene'), 1)]
